# %% [markdown]
# # Introduction

# %% [markdown]
# Ši užrašų knygutė yra skirta gretutinių studijų analizei. Čia nagrinėjama gretutinių studijų pasirinkimo dinamika, ieškoma dėsningumu.

# %%
from IPython.display import Image
Image('http://www6.cityu.edu.hk/projectflame/images/indexikon/withHat.png',width=100)

# %%
Image('http://morphocode.com/wp-content/uploads/2013/07/krzywinski-hiveplot-poster.jpg',width=50)

# %% [markdown]
# ## Įvadas

# %% [markdown]
# Tai yra gretutinės studijos. Sunku nustatyti, kada įvyko pirmieji gretutinių studijų atvejai. Tačiau, gretutinės studijos yra pasaulio mastu atpažįstama akademinės kultūros dalis. Gretutinės studijos pastebimos ir Lietuvos aukštojo mokslo institucijoje. Čia bus nagrinėjamas VDU gretutinių studijų reiškinys.

# %% [markdown]
# # Teorija

# %% [markdown]
# Naudosime grafas.
# (V,E), kur V - viršūnių rinkinys, o E kraštinių rinkinys.
# $$ V =\{v_1,..., v_5\} $$
# $$ E = \{(v_1, v_2),(v_2, v_5),(v_5, v_5),(v_5, v_4),(v_5, v_4)\}$$
# Supaprastinimo vardan naudosimetokį žymėjimą: $_p,_q$ and $_r$.
# Tarkime, kad mūsų viršūnės yra trys studijų programos: teisė, politikos mokslai ir istorija.
#
# p - 'teise',
# q - 'politikos_mokslai' and
# r - 'istorija'

# %% [markdown]
# Svorio skaičiavimas:
#
# $$D - svoris$$
#
# $$D_{(p,q)}$$

# %% [markdown]
# Mūsų atveju kraštinės, jungančios du viršūnes svorys yra lygus.
#
# p - pagrindinė studijų programa
#
# q - gretutinė studijų programa
#
# n - bet kokia gretutinė programa
#
# D - kraštinės svoris
#
# $H_x$ - visi galėję rinktis studijų programą x.
#
# $S_{x,m,k}$ - studentų, įstojusių į studijų programą x, m metais ir gretutines pasirinkusių k kurse, skaičius.
#
# $m_i$, - metai, kuriuose pasirinktos gretutinės studijos.
#
# $$H_x = S_{x, 2014, 4} + S_{x, 2014, 3} + S_{x, 2014, 2} + S_{x, 2014, 1} + S_{x, 2013, 3} + S_{x, 2013, 2} + S_{x, 2013, 1} + S_{x, 2012, 2} + S_{x, 2012, 2}  + S_{x, 2011, 1}$$
#
# $$H_{x} = \sum {S_{x, x, m-2010}}$$
#
# $$H_{2014} = \sum {S_{2014, 2014, (m-2010)}}$$
#
# $$D_{(p,q)}= \frac{\sum_{(p,q)}} {\sum_{(p,n)}} \cdot \frac {1}{H_p}$$

# %% [markdown]
# Kaip atrasti dominuojantį svorį?
# $D_{(p,q)}$ yra dominuojantis, jeigu $\frac{D_{(p,q)}} {D_{(q,p)}} > 0$

# %% [markdown]
# Svorių suvienodinimas, jei $D_{(p,q)} > 0$ ir $D_{(q,p)} > 0$ ir $D_{(p,q)}  \neq D_{(q,p)}$.

# %% [markdown]
# *Apie trijų narių ryšius. Tarkime, jog turime $D_{(p,q)}$, $D_{(p,r)}$ ir $D_{(p,q)}$
# jei $D_{(p,q)} > D_{(p,r)}$ tai koks $D_{(p,r)}$?
# $$(x,y)$$

# %% [markdown]
# $(x)^{(-1)}$

# %% [markdown]
# $m_i$,
# $m_3$

# %% [markdown]
# # 1 The data

# %%
import os
import glob
import re
import codecs
import pickle

# %%
f = open("Data/edgelist.p","rb")
edgelist = pickle.loads(f.read())

f = open("Data/nodelist.p","rb")
nodelist = pickle.loads(f.read())

# %%
len(edgelist)
# Out:
# 698

# %% [markdown]
# # 2 DATAFRAMES

# %% [markdown]
# ## 2.1 EDGE DATAFRAME

# %% [markdown]
# Kuriame gretutinių studijų pasirinkimo dataframe. Šie duomenys gauti iš VDU. Šis dataframe yra pats svarbiausias mūsų tyrimui. Sukūrę jį mes jį pildysime naudodami duomenis iš kitų šaltinių. Taip pat, jį naudosime konstruodami grafą.

# %%
import pandas as pd
# Pandas settings
pd.options.display.mpl_style = 'default'
pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 7)
pd.set_option('display.width', 10)

# Loading DFs
dfe = pd.read_pickle('data/dfe.pkl')
dfn = pd.read_pickle('data/dfn.pkl')
dff = pd.read_pickle('data/dff.pkl')

# Saving DFs
import time
timestr = time.strftime("%Y-%m-%d_%H-%M")
timestrless = time.strftime("%Y-%m-%d")
#dfe.to_pickle('data/dfe.pkl')
#dfn.to_pickle('data/dfn.pkl')
#dff.to_pickle('data/dff.pkl')

#dfe.to_pickle('data/dfe{}.pkl'.format(timestrless))
#dfn.to_pickle('data/dfn{}.pkl'.format(timestrless))
#dff.to_pickle('data/dff{}.pkl'.format(timestrless))

# %%
import json

json_data=open(r'json/get_faculty_name.json')
get_faculty_name = json.load(json_data)
json_data.close()

# %matplotlib inline
import matplotlib.pyplot as plt 

fak_colors = {'evf':'#659768', 'gmf':'#b2ce69', 'hmf':'#e6c70b', 'if':'#8cbac2', 'ktf':'#904e98',
              'mf':'#ce8d37', 'pmdf':'#58636c', 'smf':'#4667a9', 'tf':'#2a2f58', 'ma':'#00ceb9'}

fak_colors1 = {'evf':'r', 'gmf':'h', 'hmf':'b', 'if':'c', 'ktf':'k', 
               'mf':'r', 'pmdf':'g', 'smf':'b', 'tf':'c', 'ma':'y'}

programos_fakulteto_spalva = {}

def gauk_programos_fakulteto_spalva(prog):
    return fak_colors[get_faculty_name[prog]] 

facultylist = set(dfe.pagrfak.unique().tolist() + dfe.gretfak.unique().tolist())
proglist = set(dfe.pagr.unique().tolist() + dfe.gret.unique().tolist())

for x in proglist:
    programos_fakulteto_spalva[x] = gauk_programos_fakulteto_spalva(x)

# %% [markdown]
# Kaip jau minėjome, mūsų pagrindinė informacija išsaugota dviejuose DF. Viename DF išsaugota gretutinių studijų pasirinkimo informacija, o kitame - studentų stojimo duomenys.
# 1. Šioje dalyje, prie DFE pridėsime, kiek studentų rinkosi pagrindinę studijų programą.
# 2. Palyginsime su skaičiumi studentų, kurie rinkosi gretutines studijas.

# %% [markdown]
# ###### Bet kaip dėl tikrųjų svorių?

# %% [markdown]
# Kaip apskaiciuojamas grafo kraštinių svoris?
# 2014 pavasario semestro gretutinių studijų pasirinkimo svorį skaičiuosime toliau pateiktą forumulę.

# %%
# This function gets possible students of this year.
def get_number_of_current_gret_of_prog(PROG):  # Returns
    retlist = []
    for x in range(1, 9):
        dft = dfe[dfe['studsem'] == x]
        dft = dft[dft['studmet'] >= x]
        dft = dft[dft['pagr'] == PROG]
        retlist.append(len(dft))
    return sum(retlist)

def gauk_skaiciu_pagal_metus_pagr_prog(PROG, df): # Paduodame programos pavadinimą, gauname, kiek i programą istojo per paskutinius keturiu metus.
    result = 0
    yeardict = {2010:'m10', 
                2011:'m11',
                2012:'m12', 
                2013:'m13'}
    stoje_pasirinkegret = df[df[u'pavadinimas'].isin([PROG])]
    res = stoje_pasirinkegret[[yeardict[2010],
                               yeardict[2011],
                               yeardict[2012],
                               yeardict[2013]]]
    
    try:
        result = int(res.values.sum(axis=1))
        return result
    except:
        return result

# Dictionary that gets number of current students and year
mydict = {}
for x in proglist:
    ret1 = gauk_skaiciu_pagal_metus_pagr_prog(x, dfn)
    ret2 = get_number_of_current_gret_of_prog(x)
    ret2 = float(ret2)
    try:
        ret1 = float(ret1)
    except:
        pass
    mydict[x] = [ret2, ret1]

# In this part we get something, by diving to values we got in previous cell
tikrasis_gret_pop = [[x, mydict[x][0] / mydict[x][1]]
                     for x in proglist 
                     if (type(mydict[x][1]) == float) 
                     and (mydict[x][1] != 0)]

dft = pd.DataFrame([x[1] for x in tikrasis_gret_pop],
                   [x[0] for x in tikrasis_gret_pop],
                   columns=['santykis'])

dft['visostojo'] = [mydict[x][1] for x in dft.index]
dft.add = [x in range(20)]

TTL = 'Koks procentas studentu renkasi gretutines(is siuo metu studijuojanciu)'
dft['visostojo'] = list([mydict[x][1] for x in dft.index])

# FOR GRET GRET GRET
def get_number_of_current_students_getting_the_GRET_of_the_prog(PROG):
    retlist = []
    for x in range(1, 9):
        dft = dfe[dfe[u'studsem'] == x]
        dft = dft[dft[u'gretpradz'] >= x]
        dft = dft[dft[u'gret'] == PROG]
        ret = len(dft)
        retlist.append(ret)
    return sum(retlist)

# Kiek studentų šiuo metu turi šias gretutines.

dfn.set_index(dfn.pavadinimas.values, inplace=True)

dfn = pd.concat([dfn,dft],axis=1)
dfe[dfe.loc[:,'vardas'].str.contains(u"yte |aite |iute |iene | ytė |aitė |iutė |ienė")]['gim'] = 'mot'

# %%
dfe[dfe.loc[:,'vardas'].str.contains(u"yte |aite |iute |iene | ytė |aitė |iutė |ienė")]['gim'] = 'mot'
# Out:
# Index([u'pagr', u'gret', u'studmet', u'vardas', u'pagrfak', u'gretfak', u'gretpradz', u'gretpab', u'saltinionr', u'studsem', u'metulaikas', u'pagrpop', u'pagrall', u'gretpop', u'gretall'], dtype='object')

# %%
import numpy as np
df = []
df = dfn.loc[:,['santykis','visostojo']]
df = df[np.isfinite(df['santykis'])]
of_minor = [get_number_of_current_students_getting_the_GRET_of_the_prog(x)
            for x in df.index]
df
# Out:
#                               santykis  \
# anglu_filologija              0.032070
# anglu_ir_vokieciu_filologija  0.014706
# aplinkotyra_ir_ekologija      0.003937
# ...                                ...
# viesasis_administravimas      0.002075
# viesoji_komunikacija          0.002837
# vokieciu_filologija           0.000000
#
#                               visostojo
# anglu_filologija                    343
# anglu_ir_vokieciu_filologija         68
# aplinkotyra_ir_ekologija            254
# ...                                 ...
# viesasis_administravimas            482
# viesoji_komunikacija                705
# vokieciu_filologija                  16
#
# [38 rows x 2 columns]

# %%
fig = plt.figure(num=None,
                 figsize=(5, 5),
                 dpi=80,
                 facecolor='w',
                 edgecolor='k')

labels = df.index
ax = fig.add_subplot(111)
ax.set_title(u'Išeinantys prieš ateinančius')
ax.set_xlabel(u'Pasirinke šią gretutinių studijų programą')
ax.set_ylabel(u'Šios studijų programos skaičius')
plt.scatter(of_minor, 
            df.santykis, 
            s=(df.visostojo * 3), 
            c=[programos_fakulteto_spalva[x] for x in df.index],
            alpha=0.7)

for label, x, y in zip(labels, of_minor, df.santykis):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-10, 10),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.3', fc = 'grey', alpha = 0.1),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show()

# %%
import mpld3
fig = plt.figure(num=None,
                 figsize=(5, 5),
                 dpi=80,
                 facecolor='w',
                 edgecolor='k')

scatter = plt.scatter(of_minor, 
                      df.santykis, 
                      s=(df.visostojo * 3), 
                      c=[programos_fakulteto_spalva[x] for x in df.index],
                      alpha=0.7)

ax.grid(color='white', linestyle='solid')

#for label, x, y in zip(labels, of_minor, srtd.santykis):
#    plt.annotate(
#        label, 
#        xy = (x, y), xytext = (-10, 10),
#        textcoords = 'offset points', ha = 'right', va = 'bottom',
#        bbox = dict(boxstyle = 'round,pad=0.3', fc = 'grey', alpha = 0.1),
#        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
ax.set_title(u'Išeinantys prieš ateinančius')
ax.set_xlabel(u'Pasirinke šią gretutinių studijų programą')
ax.set_ylabel(u'Šios studijų programos skaičius')

labels = [x.decode('utf-8') for x in df.index]
tooltip = mpld3.plugins.PointLabelTooltip(scatter,labels=labels)  # labels=labels
mpld3.plugins.connect(fig, tooltip)

mpld3.display()
# Out:
# <style>
#
# </style>
#
# <div id="fig_el53762792255125897222698"></div>
# <script>
# function mpld3_load_lib(url, callback){
#   var s = document.createElement('script');
#   s.src = url;
#   s.async = true;
#   s.onreadystatechange = s.onload = callback;
#   s.onerror = function(){console.warn("failed to load library " + url);};
#   document.getElementsByTagName("head")[0].appendChild(s);
# }
#
# if(typeof(mpld3) !== "undefined" && mpld3._mpld3IsLoaded){
#    // already loaded: just create the figure
#    !function(mpld3){
#
#        mpld3.draw_figure("fig_el53762792255125897222698", {"axes": [{"xlim": [-20.0, 140.0], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [], "zoomable": true, "images": [], "xdomain": [-20.0, 140.0], "ylim": [-0.02, 0.14000000000000001], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "bottom", "nticks": 9, "tickvalues": null}, {"scale": "linear", "tickformat": null, "grid": {"color": "#000000", "alpha": 1.0, "dasharray": "2,2", "gridOn": true}, "fontsize": 10.0, "position": "left", "nticks": 10, "tickvalues": null}], "lines": [], "markers": [], "id": "el5376262400824", "ydomain": [-0.02, 0.14000000000000001], "collections": [{"paths": [[[[0.0, -0.5], [0.13260155, -0.5], [0.25978993539242673, -0.44731684579412084], [0.3535533905932738, -0.3535533905932738], [0.44731684579412084, -0.25978993539242673], [0.5, -0.13260155], [0.5, 0.0], [0.5, 0.13260155], [0.44731684579412084, 0.25978993539242673], [0.3535533905932738, 0.3535533905932738], [0.25978993539242673, 0.44731684579412084], [0.13260155, 0.5], [0.0, 0.5], [-0.13260155, 0.5], [-0.25978993539242673, 0.44731684579412084], [-0.3535533905932738, 0.3535533905932738], [-0.44731684579412084, 0.25978993539242673], [-0.5, 0.13260155], [-0.5, 0.0], [-0.5, -0.13260155], [-0.44731684579412084, -0.25978993539242673], [-0.3535533905932738, -0.3535533905932738], [-0.25978993539242673, -0.44731684579412084], [-0.13260155, -0.5], [0.0, -0.5]], ["M", "C", "C", "C", "C", "C", "C", "C", "C", "Z"]]], "edgecolors": ["#EEEEEE"], "edgewidths": [0.5], "offsets": "data01", "yindex": 1, "id": "el5376279193752", "pathtransforms": [[35.64225540521209, 0.0, 0.0, 35.64225540521209, 0.0, 0.0], [15.869840952317446, 0.0, 0.0, 15.869840952317446, 0.0, 0.0], [30.671497204093914, 0.0, 0.0, 30.671497204093914, 0.0, 0.0], [15.275252316519467, 0.0, 0.0, 15.275252316519467, 0.0, 0.0], [11.86342028003479, 0.0, 0.0, 11.86342028003479, 0.0, 0.0], [17.21325931647741, 0.0, 0.0, 17.21325931647741, 0.0, 0.0], [25.312857221987816, 0.0, 0.0, 25.312857221987816, 0.0, 0.0], [37.908271353848846, 0.0, 0.0, 37.908271353848846, 0.0, 0.0], [7.200822998230955, 0.0, 0.0, 7.200822998230955, 0.0, 0.0], [10.363754503432018, 0.0, 0.0, 10.363754503432018, 0.0, 0.0], [18.856180831641264, 0.0, 0.0, 18.856180831641264, 0.0, 0.0], [15.275252316519467, 0.0, 0.0, 15.275252316519467, 0.0, 0.0], [30.123203803835466, 0.0, 0.0, 30.123203803835466, 0.0, 0.0], [12.765694770084508, 0.0, 0.0, 12.765694770084508, 0.0, 0.0], [16.32993161855452, 0.0, 0.0, 16.32993161855452, 0.0, 0.0], [21.773242158072694, 0.0, 0.0, 21.773242158072694, 0.0, 0.0], [19.53155092360772, 0.0, 0.0, 19.53155092360772, 0.0, 0.0], [25.676044462869655, 0.0, 0.0, 25.676044462869655, 0.0, 0.0], [18.658728470829626, 0.0, 0.0, 18.658728470829626, 0.0, 0.0], [24.87003253955488, 0.0, 0.0, 24.87003253955488, 0.0, 0.0], [16.44294287438749, 0.0, 0.0, 16.44294287438749, 0.0, 0.0], [13.877773329774218, 0.0, 0.0, 13.877773329774218, 0.0, 0.0], [40.688518719112345, 0.0, 0.0, 40.688518719112345, 0.0, 0.0], [15.63471919941143, 0.0, 0.0, 15.63471919941143, 0.0, 0.0], [33.05438840143003, 0.0, 0.0, 33.05438840143003, 0.0, 0.0], [12.018504251546632, 0.0, 0.0, 12.018504251546632, 0.0, 0.0], [23.72684056006958, 0.0, 0.0, 23.72684056006958, 0.0, 0.0], [26.034165586355513, 0.0, 0.0, 26.034165586355513, 0.0, 0.0], [16.555182695279267, 0.0, 0.0, 16.555182695279267, 0.0, 0.0], [22.110831935702667, 0.0, 0.0, 22.110831935702667, 0.0, 0.0], [55.64437344688407, 0.0, 0.0, 55.64437344688407, 0.0, 0.0], [12.018504251546632, 0.0, 0.0, 12.018504251546632, 0.0, 0.0], [11.221672153735641, 0.0, 0.0, 11.221672153735641, 0.0, 0.0], [29.18650119236377, 0.0, 0.0, 29.18650119236377, 0.0, 0.0], [17.638342073763937, 0.0, 0.0, 17.638342073763937, 0.0, 0.0], [42.25145187073676, 0.0, 0.0, 42.25145187073676, 0.0, 0.0], [51.099032389186306, 0.0, 0.0, 51. ...
#    }(mpld3);
# }else if(typeof define === "function" && define.amd){
#    // require.js is available: use it to load d3/mpld3
#    require.config({paths: {d3: "https://mpld3.github.io/js/d3.v3.min"}});
#    require(["d3"], function(d3){
#       window.d3 = d3;
#       mpld3_load_lib("https://mpld3.github.io/js/mpld3.v0.2.js", function(){
#
#          mpld3.draw_figure("fig_el53762792255125897222698", {"axes": [{"xlim": [-20.0, 140.0], "yscale": "linear", "axesbg": "#EEEEEE", "texts": [], "zoomable": true, "images": [], "xdomain": [-20.0, 140.0], "ylim": [-0.02, 0.14000000000000001], "paths": [], "sharey": [], "sharex": [], "axesbgalpha": null, "axes": [{"scale": "linear", "tickformat": null, "grid": {"color": "#000

# %% [markdown]
# # 3. Faculty level analysis

# %% [markdown]
# <p>
# <l>Now, when we have our dataframes ready, we can dive deeper into the analysis. First, let's see what we can do.</l>
# <l>First, lets begin by analysing faculty level. But before we start it we have to recognise some things. First, it is not really abotu faculty level, it is about the reduction to faculty level. The data will include all individual cases. </l>
# <l>At this moment, our focus is on faculty level, we will dive deeper, of course, but lets wait for a bit.</l>
# <l>So, lets look how we filter </l>
# </p>

# %%
# This shows ho we filter to entries of one faculty. In this case we look at the source of academic minor
dfe[dfe['pagrfak'].isin(['hmf'])]
# Out:
#                           pagr  \
# 1          prancuzu_filologija
# 8                     istorija
# 17         prancuzu_filologija
# ..                         ...
# 686                   istorija
# 688  baltijos_regiono_kulturos
# 690           anglu_filologija
#
#                       gret  \
# 1         anglu_filologija
# 8    ekonomika_ir_finansai
# 17       marketingo_vadyba
# ..                     ...
# 686   religijos_pedagogika
# 688     socialine_politika
# 690                  teise
#
#      studmet  \
# 1          1
# 8          1
# 17         1
# ..       ...
# 686        1
# 688        2
# 690        1
#
#                     vardas  \
# 1        Pakalenkaitė Ugnė
# 8        Martinkutė Julija
# 17       Bačiulytė Modesta
# ..                     ...
# 686    Gintaute Kulvietyte
# 688  Ugne Barbora Starkute
# 690       Benas Bardauskas
#
#     pagrfak  \
# 1       hmf
# 8       hmf
# 17      hmf
# ..      ...
# 686     hmf
# 688     hmf
# 690     hmf
#
#       ...    \
# 1     ...
# 8     ...
# 17    ...
# ..    ...
# 686   ...
# 688   ...
# 690   ...
#
#     metulaikas  \
# 1            1
# 8            1
# 17           1
# ..         ...
# 686          1
# 688          1
# 690          1
#
#       pagrpop  \
# 1    0.181818
# 8    0.273469
# 17   0.181818
# ..        ...
# 686  0.273469
# 688       NaN
# 690  0.157434
#
#     pagrall  \
# 1        10
# 8        17
# 17       10
# ..      ...
# 686      17
# 688     NaN
# 690      18
#
#       gretpop  \
# 1    0.157434
# 8    0.020619
# 17   0.039326
# ..        ...
# 686  0.179487
# 688       NaN
# 690  0.096890
#
#      gretall
# 1         18
# 8         32
# 17        35
# ..       ...
# 686        2
# 688      NaN
# 690       56
#
# [257 rows x 15 columns]

# %%
# This is another look, we see all cases when someone chooses an entry in other faculty.
dfe[dfe['gretfak'].isin(['smf'])]
# Out:
#                           pagr  \
# 26                   biologija
# 28           marketingo_vadyba
# 29           marketingo_vadyba
# ..                         ...
# 685                      teise
# 688  baltijos_regiono_kulturos
# 689               psichologija
#
#                              gret  \
# 26                     pedagogika
# 28                   psichologija
# 29                   psichologija
# ..                            ...
# 685                  psichologija
# 688            socialine_politika
# 689  sociologija_ir_antropologija
#
#      studmet  \
# 26         2
# 28         1
# 29         1
# ..       ...
# 685        1
# 688        2
# 689        1
#
#                     vardas  \
# 26   Smelstoriūtė Kristina
# 28      Jakubauskytė Vaida
# 29       Vasilūnaitė Indrė
# ..                     ...
# 685          Simona sukyte
# 688  Ugne Barbora Starkute
# 689      Gabija Kisieliute
#
#     pagrfak  \
# 26      gmf
# 28      evf
# 29      evf
# ..      ...
# 685      tf
# 688     hmf
# 689     smf
#
#       ...    \
# 26    ...
# 28    ...
# 29    ...
# ..    ...
# 685   ...
# 688   ...
# 689   ...
#
#     metulaikas  \
# 26           1
# 28           1
# 29           1
# ..         ...
# 685          1
# 688          1
# 689          1
#
#       pagrpop  \
# 26   0.052023
# 28   0.039326
# 29   0.039326
# ..        ...
# 685  0.096890
# 688       NaN
# 689  0.128814
#
#     pagrall  \
# 26       13
# 28       35
# 29       35
# ..      ...
# 685      56
# 688     NaN
# 689     115
#
#       gretpop  \
# 26        NaN
# 28   0.128814
# 29   0.128814
# ..        ...
# 685  0.128814
# 688       NaN
# 689  0.013514
#
#      gretall
# 26       NaN
# 28       115
# 29       115
# ..       ...
# 685      115
# 688      NaN
# 689        3
#
# [213 rows x 15 columns]

# %%
# dataframe for faculties

rez1 = [len(dfe[dfe['pagrfak'].isin([x])]) for x in facultylist]  # Gretutines pasirinkusių fakulto studentų skaičius.
rez2 = [len(dfe[dfe['pagrfak'].isin([x]) & ~dfe['gretfak'].isin([x])]) for x in facultylist]  # Gretutines fakulteto išorėje pasirinkusių studentų skaičius.
rez3 = [len(dfe[dfe['pagrfak'].isin([x]) & dfe['gretfak'].isin([x])]) for x in facultylist]
#rez3_1 = [rez1[x] - rez2[x] for x in range(len(rez1))]  # Gretutines tame pačiame fakultete pasirinkusių studentų skaičius. # rez3 == rez3_1

rez4 = [len(dfe[dfe['gretfak'].isin([x])]) for x in facultylist] 
rez5 = [len(dfe[dfe['gretfak'].isin([x]) & ~dfe['pagrfak'].isin([x])]) for x in facultylist]

rex = [rez1, rez2, rez3, rez4, rez5]
headers = ['is_fak','is_fak_out','to_same_fak','i_fak','i_fak_is_isores']
dft = pd.DataFrame(rex, index=headers, columns=facultylist)
dff = dft.T


# Sudėti šiuos du 

dft1 = pd.DataFrame([rez2,rez3], index=['is_fak_out','to_same_fak'], columns=facultylist)
dft2 = dft1.T
dft2['procentas'] = (dft2.is_fak_out / dft2.to_same_fak) * 10
dft2 = dft2.drop('procentas', 1)
dft2['programu_fakultete'] = dfn.groupby(['fakultetas']).size()
dft2['programu_NEfakultete'] = len(proglist) - dfn.groupby(['fakultetas']).size()
dft2['TSF_atsizvelgus_i_PF'] = (dft2.is_fak_out / dft2.programu_NEfakultete)
dft2['IFO_atsizvelgus_i_PF'] = (dft2.to_same_fak / (dft2.programu_fakultete - 1)) # nes negali i ta pacia
dft2['TSF_IFO_procentas'] = dft2.TSF_atsizvelgus_i_PF / dft2.IFO_atsizvelgus_i_PF * 50

srtd = dft2.sort('TSF_IFO_procentas',ascending=True)
srtd.head()
# Out:
#      is_fak_out  \
# tf           81
# smf          46
# evf          18
# gmf          33
# if           17
#
#      to_same_fak  \
# tf             0
# smf           42
# evf            9
# gmf           23
# if             3
#
#      programu_fakultete  \
# tf                    1
# smf                   6
# evf                   5
# gmf                   7
# if                    3
#
#      programu_NEfakultete  \
# tf                     60
# smf                    55
# evf                    56
# gmf                    54
# if                     58
#
#      TSF_atsizvelgus_i_PF  \
# tf               1.350000
# smf              0.836364
# evf              0.321429
# gmf              0.611111
# if               0.293103
#
#      IFO_atsizvelgus_i_PF  \
# tf                    inf
# smf              8.400000
# evf              2.250000
# gmf              3.833333
# if               1.500000
#
#      TSF_IFO_procentas
# tf            0.000000
# smf           4.978355
# evf           7.142857
# gmf           7.971014
# if            9.770115

# %% [markdown]
# ###### Preparation for plotting.

# %%
# Ar palikti fakultetus, kurie turi labai mažai studentų? Manau reikia atsisakyti MA ir TF.
# Kaip pridėti procentinę liniją?

# Šiuos duomenis galime patikslinti, atsižvelgiant į pasirinkimo galimybę. 
# Kiek Buvo galima pasirinkti programų fakulteto viduje? 
# Teisės fakulteto studentai turėjo 0 galimybių pasirinkti fakulteto viduje.
# Didesnį pasirinkimą turėjo HMF, SMF ir kitų programų studentai.
# HMF, nepaisydami didelio pasirinkimo, juda į 
# SMF, linkę likti tame pačiame fakultete.
# GMF, linkę likti ten pat.
# PMDF, didelis judėjimas į išorę, vidutinis pasirinkimas.

# Kas tiesa, tas nemelas. Sunku įvertinti programų pasirinkimą, klausimai: 
# "apie kiek programų studentai svarstė" ir 
#  "kiek tuo metu programų buvo"?
srtd.sort('TSF_IFO_procentas',ascending=True).plot(kind='barh', alpha=1)

# %% [markdown]
# Būtina atsžvelgti, jog ne visi gali judėti į kitą fakultetą. Geriausias to pavyzdys - teisės fakultetas. Jame - tik viena studijų programa. Toliau esančiame grafe tai ir darome.

# %%
fig = plt.figure(num=None,
                 figsize=(5, 5),
                 dpi=80,
                 facecolor='w',
                 edgecolor='k')

labels = dft2.index.unique()
plt.subplots_adjust(bottom = 0.1)

ax = fig.add_subplot(111)
ax.set_title(u'Fakulteto ribose ir už tarpfakultetiniai')
ax.set_xlabel(u'Į kitus fakultetus')
ax.set_ylabel(u'Lieka fakultete')

COLORS = [fak_colors[x] for x in facultylist]

plt.scatter(dft2.TSF_atsizvelgus_i_PF, 
            dft2.IFO_atsizvelgus_i_PF, 
            alpha=0.7, 
            color=COLORS, 
            s=dft2.programu_fakultete * 100)

for label, x, y in zip(labels, dft2.TSF_atsizvelgus_i_PF, dft2.IFO_atsizvelgus_i_PF):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-10, 10),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.3', fc = 'grey', alpha = 0.1),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))
##########################
# padaryti ta pati, tik atskiroms programoms.
##########################
plt.show()

# %% [markdown]
# # Pairs of faculties

# %% [markdown]
# ## HMF and SMF

# %%
import matplotlib.pyplot as plt

plt.figure()
# Example with HMF and SMF
fltrd1 = dfe[dfe['pagrfak'].isin(['hmf'])]
fltrd2 = fltrd1[fltrd1['gretfak'].isin(['smf'])]
grpd = fltrd2.groupby(['gret']).size().order('gret')
#grpd.plot(title='hmf studentai renkasi smf gretutines', kind='barh')
#grpd
#plt.show()
# Out:
# C:\Users\Saonkfas\Anaconda\lib\site-packages\pandas\core\series.py:1686: FutureWarning: na_last is deprecated. Please use na_position instead
#   FutureWarning)

# %%
fltrd1 = dfe[dfe['pagrfak'].isin(['smf'])]
fltrd2 = fltrd1[fltrd1['gretfak'].isin(['hmf'])]
grpd = fltrd2.groupby(['gret']).size().order('gret')
#grpd.plot(title='smf studentai renkasi hmf gretutines', kind='barh')
#plt.show()

# %% [markdown]
# # 4 One faculty analysis

# %% [markdown]
# ### Faculty of social sciences

# %%
# Lets analyse SMF
plt.figure()
smf = dfe[dfe['pagrfak'].isin(['smf'])]
grpd = smf.groupby('gretfak').size().order(ascending=True)
grpd.plot(kind='barh',title=u'Kokių fakultetų gretutines renkasi SMF studentai?')

# %%
plt.figure()
grpd1 = smf.groupby('studsem').size() #Studsem, not very interesting. But I should make them all.
grpd1.plot(kind='barh',title=u'Kokiame semestre stoja smf studentai?')

# %% [markdown]
# ## SMF į HMF

# %%
# Kokių HMF programų studentai labiausiai linkę rinktis SMF gretutines?
dfh2s = dfe[dfe.pagrfak.isin(['hmf']) & dfe.gretfak.isin(['smf'])]
TITLE = u'Kokių HMF programų studentai labiausiai linkę rinktis SMF gretutines?'
dfh2s.groupby('pagr').size().order(ascending=True).plot(kind='barh', title=TITLE)

# %%
# Kokias SMF gretutines labiausiai linke rinktis HMF studentai?
dfh2s.groupby('gret').size().order(ascending=True).plot(kind='barh')

# %%
# Faculty Ego(INTERNAL)graph
faculty_internal_ego_graph = [dfe[dfe.pagrfak.isin([x]) & dfe.gretfak.isin([x])] for x in facultylist]
[x.groupby(['studsem']).size() for x in faculty_internal_ego_graph][0]
[x.groupby(['gretfak']).size() for x in faculty_internal_ego_graph]
# Out:
# [gretfak
#  mf         5
#  dtype: int64, Series([], dtype: int64), gretfak
#  gmf        23
#  dtype: int64, gretfak
#  evf        9
#  dtype: int64, Series([], dtype: int64), gretfak
#  smf        42
#  dtype: int64, gretfak
#  hmf        38
#  dtype: int64, gretfak
#  pmdf       14
#  dtype: int64, gretfak
#  ktf        1
#  dtype: int64, gretfak
#  if         3
#  dtype: int64]

# %% [markdown]
# # 5 NetworkX

# %% [markdown]
# ## 5.1 NetworkX allows us to get more data

# %%
import networkx as nx
import mpld3

# Create the graph object.
G = nx.MultiDiGraph()
GF = nx.MultiDiGraph() # Graph of faculty level
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %% [markdown]
# Gaukime duomenis iš Pandas.

# %%
pd2nx = dfe.T.to_dict() #pandas to networkx
pd2nx1 = [(pd2nx[x]['pagr'],
           pd2nx[x]['gret'],
           {'gretall': pd2nx[x]['gretall'],
            'gretfak': pd2nx[x]['gretfak'],
            'gretpab': pd2nx[x]['gretpab'],
            'gretpop': pd2nx[x]['gretpop'],
            'gretpradz': pd2nx[x]['gretpradz'],
            'pagrall': pd2nx[x]['pagrall'],
            'pagrfak': pd2nx[x]['pagrfak'],
            'pagrpop': pd2nx[x]['pagrpop'],
            'saltinionr': pd2nx[x]['saltinionr'],
            'studmet': pd2nx[x]['studmet'],
            'studsem': pd2nx[x]['studsem'],
            'vardas': pd2nx[x]['vardas']}) 
            for x in range(len(pd2nx))]

# Add edges and their attributes (nodes are included).
G.add_edges_from(pd2nx1)

# Add node attributes.
for x in G.nodes():
    G.node[x]['fakultetas'] = get_faculty_name[x]
    #add more?
    
#G.nodes(data=True)
#G.edges(data=True)
len(G.nodes()),len(G.edges())
# Out:
# (61, 698)

# %% [markdown]
# ###### SUB GRAPHS

# %% [markdown]
# Lets start by crating an internal graph. The criteria is simple, all nodes of graph have to be in same faculty.

# %%
facultylist
# Out:
# {u'evf', u'gmf', u'hmf', u'if', u'ktf', u'ma', u'mf', u'pmdf', u'smf', u'tf'}

# %% [markdown]
# ### 5.1 Program graphs

# %% [markdown]
# ### 5.1.1 Program ego graphs

# %%
# This is FACULTY GRAPH. I SHOULD MOVE IT. But no, it focus on level of programs.
faculty = u'hmf'
GHMF=nx.Graph([(u,v,d) for u,v,d in G.edges(data=True) if d[u'pagrfak'] == faculty or d[u'gretfak'] == faculty])

# Dictionary of faculty Egographs
# Move to another place.
mydict = {}
for x in facultylist:
    graph = nx.MultiDiGraph([(u,v,d) for u,v,d in G.edges(data=True) if d['pagrfak'] == x or d['gretfak'] == x])
    mydict[x] = graph

# %% [markdown]
# ### 5.1.2 Pairs of programs

# %%
#This place should contain pairs of programs.  What we can say about how philosophy interacts with law?
x,y =u'hmf',u'pmdf'
fakpair = {}
fakpair['hmfsmf'] = nx.MultiDiGraph([(u,v,d) for u,v,d in G.edges(data=True) if d['pagrfak'] == x and d['gretfak'] == y])
# Also, how many different interaction possibilities do we have? What are the trends of interaction?
fakpair
# Out:
# {'hmfsmf': <networkx.classes.multidigraph.MultiDiGraph at 0xe99d048>}

# %% [markdown]
# ### 5.1.3 Program triplets

# %%
# This is still not working but someday I will be able to use deque.
from collections import deque
triplet = deque(['filosofija','etnologija','teologija'])
triplet1 = deque(['filosofija','teologija','etnologija'])
triplet2 = deque(['etnologija','filosofija','teologija'])
triplet1.rotate(1)
trplt = triplet1.rotate(1)
trplt





headers = [u'pagr', u'gret', u'pagrfak', u'gretfak', u'Weight']
def haha(x, y, z):
    filtered = dfe[dfe.pagr.isin([x]) & dfe.gret.isin([y])]
    
    if len(filtered) > 0:
        grpd = filtered.groupby([u'gret', u'pagr']).size()
        filtered1 = dfe[dfe.pagr.isin([y]) & dfe.gret.isin([z])]
        
        if len(filtered1) > 0:
            grpd1 = filtered1.groupby([u'gret', u'pagr']).size()
            filtered2 = dfe[dfe.pagr.isin([z]) & dfe.gret.isin([x])]
            
            if len(filtered2) > 0:
                grpd2 = filtered2.groupby([u'gret', u'pagr']).size()
                ret = [len(filtered), len(filtered1), len(filtered2)]
                ret1 = len(filtered) * len(filtered1) * len(filtered2)
                ret2 = [grpd, grpd1, grpd2]

                print(x, y, z, ret1)
                return[ret, ret1, ret2]

def haha2(x, y, z):
    filtered = dfe[dfe.pagr.isin([x]) & dfe.gret.isin([y])]

    if len(filtered) > 0:
        filtered1 = dfe[dfe.pagr.isin([y]) & dfe.gret.isin([z])]

        if len(filtered1) > 0:
            filtered2 = dfe[dfe.pagr.isin([z]) & dfe.gret.isin([x])]

            if len(filtered2) > 0:
                ret = [len(filtered), len(filtered1), len(filtered2)]
                ret1 = len(filtered) * len(filtered1) * len(filtered2)
                
                return([x, y, z], ret, ret1)

def ha():
    thelist = []
    seenlist = []
    count = 0
    for k in proglist:
        count += 1
        for l in proglist:
            for m in proglist:
                seenlist.append([k, l, m])
                if[k, l, m] in seenlist is not True:
                    rez = haha2(k, l, m)
                    if rez is not None:
                        thelist.append(deque(rez))
                        print (rez)
    return thelist

import pickle

#alltriplets = ha()
f = open("Data/alltriplets.p","rb")

bin_data = f.read()
alltriplets = pickle.loads(bin_data)

#f = open("Data/alltriplets_unicode.p","rb")
#alltriplets  = pickle.load(f)

#pickle.dump(alltriplets, open( "Data/alltriplets.p", "wb" ))
#pickle.dump(unicode(alltriplets), open( "Data/alltriplets_unicode.p", "wb" ))

#TRIPLETS
rez = [x for x in alltriplets]
trip_df = pd.DataFrame(rez)

# %% [markdown]
# The following are not triplets

# %%
SG = mydict[faculty]
for x in SG.nodes():
    SG.node[x]['fakultetas'] = get_faculty_name[x]

all_faculties_in_graph = [get_faculty_name[x] for x in SG.nodes()]

# %%
list_of_node_lists = []
for FAK in set(all_faculties_in_graph):
    node_list = []
    node_list = [n for n, attrdict in SG.node.items() if attrdict["fakultetas"] == FAK]
    list_of_node_lists.append(node_list)

# %%
### Developing a colored version.
#from mpld3 import enable_notebook
#enable_notebook()

def draw_graphs(faculty):
    G = mydict[faculty]
    for x in G.nodes():
       G.node[x]['fakultetas'] = get_faculty_name[x]
          
    plt.figure(figsize=(10, 10))
    plt.title('{}'.format(faculty))
    
    pos=nx.spring_layout(G, iterations=100)
    
    all_faculties_in_graph = [get_faculty_name[x] for x in G.nodes()]
    rez = set(all_faculties_in_graph)
   # weights = [n for n, attrdict in G.edge.items() if attrdict["fakultetas"] == "hmf"]
    count = 0
    for x in rez:
        count += 1
        nx.draw_networkx_nodes(G,
                               pos,
                               #nodelist=G.nodes()[5:-1],
                               nodelist=[z for z in G.nodes() if get_faculty_name[z] == x],
                               node_color=fak_colors[x],
                               node_size=500,
                               alpha=0.5)
    
    count = 0
    for x in rez:
        nx.draw_networkx_edges(G,
                               pos,
         #                      edgelist=G.edges(),
                               edgelist = [(u,v,d) for u,v,d in G.edges(data=True) if get_faculty_name[u] == x],
                               width=2,
                               alpha=0.2,
                               weight=1,
                               edge_color=fak_colors[x])

        #add nx.draw_networkx_edges... if u and v already in graph
    nx.draw_networkx_labels(G, 
                             pos, 
                             labels=None, 
                             font_size=10, 
                             font_color='k', 
                             font_family='sans-serif', 
                             font_weight='normal', 
                             alpha=0.6, 
                             ax=None)
    plt.show()
[draw_graphs(x) for x in facultylist]
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %%
# Wonderful, but lets do the same for 
#EACH PROGRAM! PROGRAMS EGO NETWORK
#INTERNAL FACULTY RELATIONS

# %%
# Let's do internal faculty

# %%
# Let's do favorite locations of each faculty. Which faculty do they like to go to

# %%
# Let's do STUDSEM paterns

# %%
# Let's do changes of faculty patterns. What amount of people go where, is it continuous or is it fluctuating?

# %%
# Let's do some tweaks for pring layout.

# %% [markdown]
# ## 5.2 Faculty graphs (where relations between faculties are analysed)

# %% [markdown]
# ### 5.2.1 Ego

# %% [markdown]
# ### 5.2.2 Twin(pair)

# %%
# Works only with two graphs
GHSC = nx.compose(mydict['hmf'],mydict['smf'])
len(GHSC.edges()), len(GHSC.nodes())
# Out:
# (469, 56)

# %%
dfe
# Out:
#                       pagr  \
# 0               biochemija
# 1      prancuzu_filologija
# 2     viesoji_komunikacija
# ..                     ...
# 695               menotyra
# 696  kurybines_industrijos
# 697      marketingo_vadyba
#
#                      gret  \
# 0        anglu_filologija
# 1        anglu_filologija
# 2        anglu_filologija
# ..                    ...
# 695  viesoji_komunikacija
# 696  viesoji_komunikacija
# 697  viesoji_komunikacija
#
#      studmet  \
# 0          1
# 1          1
# 2          1
# ..       ...
# 695        2
# 696        1
# 697        1
#
#                      vardas  \
# 0        Staškevičiūtė Eglė
# 1         Pakalenkaitė Ugnė
# 2           Odinaitė Dovilė
# ..                      ...
# 695  Greta Andriuskeviciute
# 696     Greta Lesciauskaite
# 697       Inesa Meskauskyte
#
#     pagrfak  \
# 0       gmf
# 1       hmf
# 2      pmdf
# ..      ...
# 695      mf
# 696      mf
# 697     evf
#
#       ...    \
# 0     ...
# 1     ...
# 2     ...
# ..    ...
# 695   ...
# 696   ...
# 697   ...
#
#     metulaikas  \
# 0            1
# 1            1
# 2            1
# ..         ...
# 695          1
# 696          1
# 697          1
#
#       pagrpop  \
# 0    0.087500
# 1    0.181818
# 2    0.073759
# ..        ...
# 695  0.077844
# 696  0.078125
# 697  0.039326
#
#     pagrall  \
# 0         9
# 1        10
# 2        61
# ..      ...
# 695      17
# 696       4
# 697      35
#
#       gretpop  \
# 0    0.157434
# 1    0.157434
# 2    0.157434
# ..        ...
# 695  0.073759
# 696  0.073759
# 697  0.073759
#
#      gretall
# 0         18
# 1         18
# 2         18
# ..       ...
# 695       61
# 696       61
# 697       61
#
# [698 rows x 15 columns]

# %% [markdown]
# We have many connections between programs. These connections are very itneresting. The most interesting thing to us is, whether we can interpret connections as one sided. We have a hypothesis, that each connection is onesided, to prove that, we have to find, how values of connections compare.
#
# If we find that connections are indeed onesided, we will enable to reduce our graph to DiGraph, that will help us to process the graph even further.
#
# We will not abandon the data, we will identify unlikely connections. That is to say, connections, that go against the stream.

# %%
def gauk_tikruosius_svorius(x,y):
    dft = dfe.loc[:,['pagr','pagrpop','pagrall']]

    x_pagrpop = dft[dft.pagr == x].drop_duplicates()['pagrpop'].values
    x_pagrall = dft[dft.pagr == x].drop_duplicates()['pagrall'].values

    y_pagrpop = dft[dft.pagr == y].drop_duplicates()['pagrpop'].values
    y_pagrall = dft[dft.pagr == y].drop_duplicates()['pagrall'].values

    x_to_y = len(dfe[dfe['pagr'].isin([x]) & dfe['gret'].isin([y])])
    y_to_x = len(dfe[dfe['pagr'].isin([y]) & dfe['gret'].isin([x])])
    
    rez = [x, y, 
           float(x_pagrpop), float(x_pagrall),  # Something wroing with returning 0 length arrays and turning them to float
           float(y_pagrpop), float(y_pagrall), 
           x_to_y, y_to_x]
    
    value1 = 0
    value2 = 0
    
    if float(rez[6]) != 0:
        value1 = (float(rez[3]) / float(rez[6]))
    if float(rez[7]) != 0:
        value2 = (float(rez[5]) / float(rez[7]))
                  
    ret = [rez[0],
           rez[1], 
           value1 * rez[2],
           value2 * rez[4]]
    return ret
x,y = 'istorija','teise'


dft = dfe.loc[:,['pagr','pagrpop','pagrall']]
dft
# Out:
#                       pagr  \
# 0               biochemija
# 1      prancuzu_filologija
# 2     viesoji_komunikacija
# ..                     ...
# 695               menotyra
# 696  kurybines_industrijos
# 697      marketingo_vadyba
#
#       pagrpop  \
# 0    0.087500
# 1    0.181818
# 2    0.073759
# ..        ...
# 695  0.077844
# 696  0.078125
# 697  0.039326
#
#      pagrall
# 0          9
# 1         10
# 2         61
# ..       ...
# 695       17
# 696        4
# 697       35
#
# [698 rows x 3 columns]

# %%
proglist
# Out:
# {u'anglu_filologija',
#  u'anglu_ir_vokieciu_filologija',
#  u'anglu_ir_vokieciu_kalba',
#  u'aplinkosauga_ir_ekologija',
#  u'aplinkotyra',
#  u'aplinkotyra_ir_ekologija',
#  u'atlikimo_menas',
#  'baltijos_regiono_kulturos',
#  u'baltijos_regiono_studijos',
#  u'bendroji_muzikos_didaktika',
#  u'biochemija',
#  u'biologija',
#  u'biotechnologija',
#  u'ekonomika',
#  u'ekonomika_ir_finansai',
#  u'energetika_ir_fizika',
#  u'energetikos_fizika',
#  'energijos_technologijos',
#  u'etnologija',
#  u'europos_ekonomika',
#  'europos_ekonomikos_studijos',
#  u'filosofija',
#  u'informatika',
#  u'istorija',
#  u'italistika_ir_romanu_kalbos',
#  u'karjera_ir_profesinis_konsultavimas',
#  u'kataliku_teologija',
#  u'konsultavimas_karjerai',
#  u'kurybines_industrijos',
#  u'lietuviu_filologija',
#  u'lietuviu_kalba',
#  u'marketingo_vadyba',
#  u'matematika_ir_jos_taikymas',
#  u'menotyra',
#  u'mokymo_paslaugu_vadyba',
#  u'mokymosi_paslaugu_vadyba',
#  'multimedija_ir_interneto_technologijos',
#  u'multimedijos_ir_interneto_technologijos',
#  u'muzikos_pedagogika',
#  u'naujuju_mediju_menas',
#  u'pedagogika',
#  u'politikos_mokslai',
#  u'prancuzu_filologija',
#  u'psichologija',
#  u'religijos_pedagogika',
#  'rytu_azijos_saliu_kultura_ir_kalbos',
#  u'rytu_azijos_saliu_kulturos_ir_kalbos',
#  u'socialine_politika',
#  u'socialinis_darbas',
#  u'sociologija',
#  'sociologija_ir_antropologija',
#  'tarptautines_politikos_ir_vystymo_studijos',
#  'teise',
#  u'vadyba',
#  u'vaidyba',
#  u'verslo_administravimas',
#  u'verslo_ir_taikomoji_informatika',
#  'viesasis_administravimas',
#  'viesoji_komunikacija',
#  u'vokieciu_filologija',
#  u'vokieciu_kalba_ir_kultura'}

# %%
rex = []
for x in proglist:
    for y in proglist:
        rezz = []
        try:
            rezz = gauk_tikruosius_svorius(x,y)
        except:
            pass
        rex.append(rezz)
rex
# Out:
# [[u'marketingo_vadyba', u'marketingo_vadyba', 0.0, 0.0],
#  [u'marketingo_vadyba',
#   u'ekonomika_ir_finansai',
#   0.6882022471910112,
#   0.32989690721649484],
#  [u'marketingo_vadyba', u'atlikimo_menas', 0.0, nan],
#  [u'marketingo_vadyba', u'istorija', 0.0, 4.648979591836735],
#  [u'marketingo_vadyba', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'marketingo_vadyba', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'marketingo_vadyba', u'kurybines_industrijos', 0.0, 0.3125],
#  [u'marketingo_vadyba', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'marketingo_vadyba', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'marketingo_vadyba', u'prancuzu_filologija', 0.0, 1.8181818181818183],
#  [u'marketingo_vadyba', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'marketingo_vadyba', u'lietuviu_kalba', 0.0, nan],
#  [u'marketingo_vadyba', u'kataliku_teologija', 0.0, 0.0],
#  [u'marketingo_vadyba', u'filosofija', 0.0, 0.0],
#  [u'marketingo_vadyba',
#   u'anglu_ir_vokieciu_filologija',
#   0.0,
#   0.17647058823529413],
#  [u'marketingo_vadyba', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'marketingo_vadyba', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'marketingo_vadyba', u'menotyra', 0.0, 0.0],
#  [u'marketingo_vadyba', u'aplinkotyra_ir_ekologija', 0.0, 0.3188976377952756],
#  [u'marketingo_vadyba', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'marketingo_vadyba', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'marketingo_vadyba', u'biotechnologija', 0.0, nan],
#  [u'marketingo_vadyba', u'muzikos_pedagogika', 0.0, nan],
#  [u'marketingo_vadyba', u'socialinis_darbas', 0.0, 0.0],
#  [u'marketingo_vadyba', u'anglu_filologija', 0.0, 0.0],
#  [u'marketingo_vadyba', 'multimedija_ir_interneto_technologijos', 0.0, nan],
#  [u'marketingo_vadyba', u'matematika_ir_jos_taikymas', 0.0, 0.0],
#  [u'marketingo_vadyba', u'ekonomika', 0.0, nan],
#  [],
#  [u'marketingo_vadyba', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'marketingo_vadyba', u'lietuviu_filologija', 0.0, 0.0],
#  [u'marketingo_vadyba', u'multimedijos_ir_interneto_technologijos', 0.0, nan],
#  [],
#  [u'marketingo_vadyba', u'naujuju_mediju_menas', 0.0, 0.38461538461538464],
#  [u'marketingo_vadyba', u'biologija', 0.0, 0.0],
#  [u'marketingo_vadyba', u'socialine_politika', 0.0, nan],
#  [u'marketingo_vadyba', u'religijos_pedagogika', 0.0, 0.0],
#  [u'marketingo_vadyba',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   0.0,
#   0.18421052631578946],
#  [u'marketingo_vadyba', u'etnologija', 0.0, 0.0],
#  [u'marketingo_vadyba', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'marketingo_vadyba', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'marketingo_vadyba', u'politikos_mokslai', 0.0, 5.29082774049217],
#  [u'marketingo_vadyba',
#   'viesoji_komunikacija',
#   1.3764044943820224,
#   0.28120567375886524],
#  [u'marketingo_vadyba', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'marketingo_vadyba', u'vadyba', 0.0, 0.0],
#  [u'marketingo_vadyba', u'vokieciu_filologija', 0.0, nan],
#  [u'marketingo_vadyba', 'energijos_technologijos', 0.0, nan],
#  [u'marketingo_vadyba',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.0],
#  [u'marketingo_vadyba', u'verslo_administravimas', 1.3764044943820224, 0.0],
#  [u'marketingo_vadyba', u'aplinkotyra', 0.0, nan],
#  [u'marketingo_vadyba',
#   u'psichologija',
#   0.6882022471910112,
#   14.813559322033898],
#  [],
#  [u'marketingo_vadyba', 'viesasis_administravimas', 0.0, 0.4315352697095436],
#  [u'marketingo_vadyba', u'biochemija', 0.0, 0.0],
#  [u'marketingo_vadyba', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'marketingo_vadyba', 'teise', 0.0, 1.3564593301435408],
#  [u'ekonomika_ir_finansai',
#   u'marketingo_vadyba',
#   0.32989690721649484,
#   0.6882022471910112],
#  [u'ekonomika_ir_finansai', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'atlikimo_menas', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'istorija', 0.0, 4.648979591836735],
#  [u'ekonomika_ir_finansai', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'kurybines_industrijos', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'prancuzu_filologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'lietuviu_kalba', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'kataliku_teologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'filosofija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'ekonomika_ir_finansai', u'menotyra', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'ekonomika_ir_finansai', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'ekonomika_ir_finansai', u'biotechnologija', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'muzikos_pedagogika', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'socialinis_darbas', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'anglu_filologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai',
#   'multimedija_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [u'ekonomika_ir_finansai',
#   u'matematika_ir_jos_taikymas',
#   0.0,
#   0.1458966565349544],
#  [u'ekonomika_ir_finansai', u'ekonomika', 0.0, nan],
#  [],
#  [u'ekonomika_ir_finansai', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'lietuviu_filologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai',
#   u'multimedijos_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [],
#  [u'ekonomika_ir_finansai', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'biologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', u'socialine_politika', 0.6597938144329897, nan],
#  [u'ekonomika_ir_finansai', u'religijos_pedagogika', 0.0, 0.0],
#  [u'ekonomika_ir_finansai',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   0.0,
#   0.5526315789473684],
#  [u'ekonomika_ir_finansai', u'etnologija', 0.0, 0.0],
#  [u'ekonomika_ir_finansai', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'ekonomika_ir_finansai', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'politikos_mokslai', 0.0, 0.8818046234153616],
#  [u'ekonomika_ir_finansai', 'viesoji_komunikacija', 0.6597938144329897, 0.0],
#  [u'ekonomika_ir_finansai', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'ekonomika_ir_finansai', u'vadyba', 0.0, 0.07692307692307693],
#  [u'ekonomika_ir_finansai', u'vokieciu_filologija', 0.0, nan],
#  [u'ekonomika_ir_finansai', 'energijos_technologijos', 0.0, nan],
#  [u'ekonomika_ir_finansai',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.20454545454545453],
#  [u'ekonomika_ir_finansai',
#   u'verslo_administravimas',
#   0.6597938144329897,
#   0.44130434782608696],
#  [u'ekonomika_ir_finansai', u'aplinkotyra', 0.0, nan],
#  [u'ekonomika_ir_finansai',
#   u'psichologija',
#   0.6597938144329897,
#   7.406779661016949],
#  [],
#  [u'ekonomika_ir_finansai',
#   'viesasis_administravimas',
#   0.0,
#   0.4315352697095436],
#  [u'ekonomika_ir_finansai', u'biochemija', 0.0, 0.7875],
#  [u'ekonomika_ir_finansai', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'ekonomika_ir_finansai', 'teise', 0.32989690721649484, 0.904306220095694],
#  [u'atlikimo_menas', u'marketingo_vadyba', nan, 0.0],
#  [u'atlikimo_menas', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'atlikimo_menas', u'atlikimo_menas', nan, nan],
#  [u'atlikimo_menas', u'istorija', nan, 0.0],
#  [u'atlikimo_menas', 'baltijos_regiono_kulturos', nan, nan],
#  [u'atlikimo_menas', u'karjera_ir_profesinis_konsultavimas', nan, nan],
#  [u'atlikimo_menas', u'kurybines_industrijos', nan, 0.0],
#  [u'atlikimo_menas', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'atlikimo_menas', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'atlikimo_menas', u'prancuzu_filologija', nan, 0.0],
#  [u'atlikimo_menas', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'atlikimo_menas', u'lietuviu_kalba', nan, nan],
#  [u'atlikimo_menas', u'kataliku_teologija', nan, 0.0],
#  [u'atlikimo_menas', u'filosofija', nan, 0.0],
#  [u'atlikimo_menas', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'atlikimo_menas', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'atlikimo_menas', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'atlikimo_menas', u'menotyra', nan, 0.0],
#  [u'atlikimo_menas', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'atlikimo_menas', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'atlikimo_menas', u'energetikos_fizika', nan, nan],
#  [],
#  [u'atlikimo_menas', u'biotechnologija', nan, nan],
#  [u'atlikimo_menas', u'muzikos_pedagogika', nan, nan],
#  [u'atlikimo_menas', u'socialinis_darbas', nan, 0.0],
#  [u'atlikimo_menas', u'anglu_filologija', nan, 0.0],
#  [u'atlikimo_menas', 'multimedija_ir_interneto_technologijos', nan, nan],
#  [u'atlikimo_menas', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'atlikimo_menas', u'ekonomika', nan, nan],
#  [],
#  [u'atlikimo_menas', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'atlikimo_menas', u'lietuviu_filologija', nan, 0.0],
#  [u'atlikimo_menas', u'multimedijos_ir_interneto_technologijos', nan, nan],
#  [],
#  [u'atlikimo_menas', u'naujuju_mediju_menas', nan, 0.0],
#  [u'atlikimo_menas', u'biologija', nan, 0.0],
#  [u'atlikimo_menas', u'socialine_politika', nan, nan],
#  [u'atlikimo_menas', u'religijos_pedagogika', nan, 0.0],
#  [u'atlikimo_menas', u'rytu_azijos_saliu_kulturos_ir_kalbos', nan, 0.0],
#  [u'atlikimo_menas', u'etnologija', nan, 0.0],
#  [u'atlikimo_menas', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  [u'atlikimo_menas', u'baltijos_regiono_studijos', nan, nan],
#  [u'atlikimo_menas', u'politikos_mokslai', nan, 0.0],
#  [u'atlikimo_menas', 'viesoji_komunikacija', nan, 0.0],
#  [u'atlikimo_menas', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'atlikimo_menas', u'vadyba', nan, 0.0],
#  [u'atlikimo_menas', u'vokieciu_filologija', nan, nan],
#  [u'atlikimo_menas', 'energijos_technologijos', nan, nan],
#  [u'atlikimo_menas', 'tarptautines_politikos_ir_vystymo_studijos', nan, 0.0],
#  [u'atlikimo_menas', u'verslo_administravimas', nan, 0.0],
#  [u'atlikimo_menas', u'aplinkotyra', nan, nan],
#  [u'atlikimo_menas', u'psichologija', nan, 0.0],
#  [],
#  [u'atlikimo_menas', 'viesasis_administravimas', nan, 0.0],
#  [u'atlikimo_menas', u'biochemija', nan, 0.0],
#  [u'atlikimo_menas', u'italistika_ir_romanu_kalbos', nan, nan],
#  [u'atlikimo_menas', 'teise', nan, 0.0],
#  [u'istorija', u'marketingo_vadyba', 4.648979591836735, 0.0],
#  [u'istorija', u'ekonomika_ir_finansai', 4.648979591836735, 0.0],
#  [u'istorija', u'atlikimo_menas', 0.0, nan],
#  [u'istorija', u'istorija', 0.0, 0.0],
#  [u'istorija', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'istorija', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'istorija', u'kurybines_industrijos', 4.648979591836735, 0.0],
#  [u'istorija', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'istorija', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'istorija', u'prancuzu_filologija', 0.0, 0.0],
#  [u'istorija', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'istorija', u'lietuviu_kalba', 0.0, nan],
#  [u'istorija', u'kataliku_teologija', 0.0, 0.0],
#  [u'istorija', u'filosofija', 1.5496598639455783, 8.625],
#  [u'istorija', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'istorija', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'istorija', u'sociologija', 4.648979591836735, nan],
#  [],
#  [],
#  [u'istorija', u'menotyra', 2.3244897959183675, 1.3233532934131738],
#  [u'istorija', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'istorija', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'istorija', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'istorija', u'biotechnologija', 0.0, nan],
#  [u'istorija', u'muzikos_pedagogika', 0.0, nan],
#  [u'istorija', u'socialinis_darbas', 2.3244897959183675, 0.0],
#  [u'istorija', u'anglu_filologija', 2.3244897959183675, 1.4169096209912537],
#  [u'istorija', 'multimedija_ir_interneto_technologijos', 0.0, nan],
#  [u'istorija', u'matematika_ir_jos_taikymas', 0.0, 0.0],
#  [u'istorija', u'ekonomika', 0.0, nan],
#  [],
#  [u'istorija', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'istorija', u'lietuviu_filologija', 0.0, 0.0],
#  [u'istorija', u'multimedijos_ir_interneto_technologijos', 0.0, nan],
#  [],
#  [u'istorija', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'istorija', u'biologija', 0.0, 0.0],
#  [u'istorija', u'socialine_politika', 0.0, nan],
#  [u'istorija', u'religijos_pedagogika', 4.648979591836735, 0.1794871794871795],
#  [u'istorija',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   2.3244897959183675,
#   0.5526315789473684],
#  [u'istorija', u'etnologija', 4.648979591836735, 0.0],
#  [u'istorija', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'istorija', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'istorija', u'politikos_mokslai', 0.332069970845481, 1.058165548098434],
#  [u'istorija', 'viesoji_komunikacija', 4.648979591836735, 4.499290780141844],
#  [u'istorija', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'istorija', u'vadyba', 0.0, 0.0],
#  [u'istorija', u'vokieciu_filologija', 0.0, nan],
#  [u'istorija', 'energijos_technologijos', 0.0, nan],
#  [u'istorija', 'tarptautines_politikos_ir_vystymo_studijos', 0.0, 0.0],
#  [u'istorija', u'verslo_administravimas', 4.648979591836735, 0.0],
#  [u'istorija', u'aplinkotyra', 0.0, nan],
#  [u'istorija', u'psichologija', 1.5496598639455783, 0.0],
#  [],
#  [u'istorija', 'viesasis_administravimas', 4.648979591836735, 0.0],
#  [u'istorija', u'biochemija', 0.0, 0.0],
#  [u'istorija', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'istorija', 'teise', 0.3874149659863946, 2.7129186602870816],
#  ['baltijos_regiono_kulturos', u'marketingo_vadyba', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'ekonomika_ir_finansai', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'atlikimo_menas', nan, nan],
#  ['baltijos_regiono_kulturos', u'istorija', nan, 0.0],
#  ['baltijos_regiono_kulturos', 'baltijos_regiono_kulturos', nan, nan],
#  ['baltijos_regiono_kulturos',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  ['baltijos_regiono_kulturos', u'kurybines_industrijos', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'bendroji_muzikos_didaktika', nan, nan],
#  ['baltijos_regiono_kulturos', u'vokieciu_kalba_ir_kultura', nan, nan],
#  ['baltijos_regiono_kulturos', u'prancuzu_filologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'anglu_ir_vokieciu_kalba', nan, nan],
#  ['baltijos_regiono_kulturos', u'lietuviu_kalba', nan, nan],
#  ['baltijos_regiono_kulturos', u'kataliku_teologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'filosofija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'verslo_ir_taikomoji_informatika', nan, nan],
#  ['baltijos_regiono_kulturos', u'sociologija', nan, nan],
#  [],
#  [],
#  ['baltijos_regiono_kulturos', u'menotyra', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  ['baltijos_regiono_kulturos', u'energetikos_fizika', nan, nan],
#  [],
#  ['baltijos_regiono_kulturos', u'biotechnologija', nan, nan],
#  ['baltijos_regiono_kulturos', u'muzikos_pedagogika', nan, nan],
#  ['baltijos_regiono_kulturos', u'socialinis_darbas', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'anglu_filologija', nan, 0.0],
#  ['baltijos_regiono_kulturos',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  ['baltijos_regiono_kulturos', u'matematika_ir_jos_taikymas', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'ekonomika', nan, nan],
#  [],
#  ['baltijos_regiono_kulturos', u'mokymo_paslaugu_vadyba', nan, nan],
#  ['baltijos_regiono_kulturos', u'lietuviu_filologija', nan, 0.0],
#  ['baltijos_regiono_kulturos',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  ['baltijos_regiono_kulturos', u'naujuju_mediju_menas', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'biologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'socialine_politika', nan, nan],
#  ['baltijos_regiono_kulturos', u'religijos_pedagogika', nan, 0.0],
#  ['baltijos_regiono_kulturos',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  ['baltijos_regiono_kulturos', u'etnologija', nan, 0.0],
#  ['baltijos_regiono_kulturos', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  ['baltijos_regiono_kulturos', u'baltijos_regiono_studijos', nan, nan],
#  ['baltijos_regiono_kulturos', u'politikos_mokslai', nan, 0.0],
#  ['baltijos_regiono_kulturos', 'viesoji_komunikacija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'mokymosi_paslaugu_vadyba', nan, nan],
#  ['baltijos_regiono_kulturos', u'vadyba', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'vokieciu_filologija', nan, nan],
#  ['baltijos_regiono_kulturos', 'energijos_technologijos', nan, nan],
#  ['baltijos_regiono_kulturos',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  ['baltijos_regiono_kulturos', u'verslo_administravimas', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'aplinkotyra', nan, nan],
#  ['baltijos_regiono_kulturos', u'psichologija', nan, 0.0],
#  [],
#  ['baltijos_regiono_kulturos', 'viesasis_administravimas', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'biochemija', nan, 0.0],
#  ['baltijos_regiono_kulturos', u'italistika_ir_romanu_kalbos', nan, nan],
#  ['baltijos_regiono_kulturos', 'teise', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'marketingo_vadyba', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'atlikimo_menas', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'istorija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   'baltijos_regiono_kulturos',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'kurybines_industrijos', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'bendroji_muzikos_didaktika',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'vokieciu_kalba_ir_kultura',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'prancuzu_filologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'anglu_ir_vokieciu_kalba',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'lietuviu_kalba', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'kataliku_teologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'filosofija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'anglu_ir_vokieciu_filologija',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'verslo_ir_taikomoji_informatika',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas', u'menotyra', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'aplinkotyra_ir_ekologija',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'aplinkosauga_ir_ekologija',
#   nan,
#   nan],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas', u'energetikos_fizika', nan, nan],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas', u'biotechnologija', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'muzikos_pedagogika', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'socialinis_darbas', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'anglu_filologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'matematika_ir_jos_taikymas',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'ekonomika', nan, nan],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'lietuviu_filologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas', u'naujuju_mediju_menas', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'biologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'socialine_politika', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'religijos_pedagogika', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'etnologija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   'sociologija_ir_antropologija',
#   nan,
#   0.0],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'baltijos_regiono_studijos',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'politikos_mokslai', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', 'viesoji_komunikacija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'mokymosi_paslaugu_vadyba',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'vadyba', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'vokieciu_filologija', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', 'energijos_technologijos', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'verslo_administravimas', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'aplinkotyra', nan, nan],
#  [u'karjera_ir_profesinis_konsultavimas', u'psichologija', nan, 0.0],
#  [],
#  [u'karjera_ir_profesinis_konsultavimas',
#   'viesasis_administravimas',
#   nan,
#   0.0],
#  [u'karjera_ir_profesinis_konsultavimas', u'biochemija', nan, 0.0],
#  [u'karjera_ir_profesinis_konsultavimas',
#   u'italistika_ir_romanu_kalbos',
#   nan,
#   nan],
#  [u'karjera_ir_profesinis_konsultavimas', 'teise', nan, 0.0],
#  [u'kurybines_industrijos', u'marketingo_vadyba', 0.3125, 0.0],
#  [u'kurybines_industrijos', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'kurybines_industrijos', u'atlikimo_menas', 0.0, nan],
#  [u'kurybines_industrijos', u'istorija', 0.0, 4.648979591836735],
#  [u'kurybines_industrijos', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'kurybines_industrijos', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'kurybines_industrijos', u'kurybines_industrijos', 0.0, 0.0],
#  [u'kurybines_industrijos', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'kurybines_industrijos', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'kurybines_industrijos', u'prancuzu_filologija', 0.0, 0.0],
#  [u'kurybines_industrijos', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'kurybines_industrijos', u'lietuviu_kalba', 0.0, nan],
#  [u'kurybines_industrijos', u'kataliku_teologija', 0.3125, 0.0],
#  [u'kurybines_industrijos', u'filosofija', 0.0, 0.0],
#  [u'kurybines_industrijos', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'kurybines_industrijos', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'kurybines_industrijos', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'kurybines_industrijos', u'menotyra', 0.3125, 0.0],
#  [u'kurybines_industrijos',
#   u'aplinkotyra_ir_ekologija',
#   0.0,
#   0.3188976377952756],
#  [u'kurybines_industrijos', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'kurybines_industrijos', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'kurybines_industrijos', u'biotechnologija', 0.0, nan],
#  [u'kurybines_industrijos', u'muzikos_pedagogika', 0.0, nan],
#  [u'kurybines_industrijos', u'socialinis_darbas', 0.0, 0.0],
#  [u'kurybines_industrijos', u'anglu_filologija', 0.0, 2.8338192419825075],
#  [u'kurybines_industrijos',
#   'multimedija_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [u'kurybines_industrijos',
#   u'matematika_ir_jos_taikymas',
#   0.0,
#   1.0212765957446808],
#  [u'kurybines_industrijos', u'ekonomika', 0.0, nan],
#  [],
#  [u'kurybines_industrijos', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'kurybines_industrijos', u'lietuviu_filologija', 0.0, 0.0],
#  [u'kurybines_industrijos',
#   u'multimedijos_ir_interneto_technologijos',
#   0.3125,
#   nan],
#  [],
#  [u'kurybines_industrijos', u'naujuju_mediju_menas', 0.10416666666666666, 0.0],
#  [u'kurybines_industrijos', u'biologija', 0.0, 0.0],
#  [u'kurybines_industrijos', u'socialine_politika', 0.0, nan],
#  [u'kurybines_industrijos', u'religijos_pedagogika', 0.0, 0.0],
#  [u'kurybines_industrijos', u'rytu_azijos_saliu_kulturos_ir_kalbos', 0.0, 0.0],
#  [u'kurybines_industrijos', u'etnologija', 0.0, 0.0],
#  [u'kurybines_industrijos', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'kurybines_industrijos', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'kurybines_industrijos', u'politikos_mokslai', 0.0, 0.0],
#  [u'kurybines_industrijos', 'viesoji_komunikacija', 0.15625, 0.0],
#  [u'kurybines_industrijos', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'kurybines_industrijos', u'vadyba', 0.0, 0.0],
#  [u'kurybines_industrijos', u'vokieciu_filologija', 0.0, nan],
#  [u'kurybines_industrijos', 'energijos_technologijos', 0.0, nan],
#  [u'kurybines_industrijos',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.0],
#  [u'kurybines_industrijos', u'verslo_administravimas', 0.0, 0.0],
#  [u'kurybines_industrijos', u'aplinkotyra', 0.0, nan],
#  [u'kurybines_industrijos', u'psichologija', 0.3125, 0.0],
#  [],
#  [u'kurybines_industrijos', 'viesasis_administravimas', 0.0, 0.0],
#  [u'kurybines_industrijos', u'biochemija', 0.0, 0.0],
#  [u'kurybines_industrijos', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'kurybines_industrijos', 'teise', 0.0, 0.0],
#  [u'bendroji_muzikos_didaktika', u'marketingo_vadyba', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'atlikimo_menas', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'istorija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', 'baltijos_regiono_kulturos', nan, nan],
#  [u'bendroji_muzikos_didaktika',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  [u'bendroji_muzikos_didaktika', u'kurybines_industrijos', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'prancuzu_filologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'lietuviu_kalba', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'kataliku_teologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'filosofija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'bendroji_muzikos_didaktika', u'menotyra', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'bendroji_muzikos_didaktika', u'energetikos_fizika', nan, nan],
#  [],
#  [u'bendroji_muzikos_didaktika', u'biotechnologija', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'muzikos_pedagogika', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'socialinis_darbas', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'anglu_filologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  [u'bendroji_muzikos_didaktika', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'ekonomika', nan, nan],
#  [],
#  [u'bendroji_muzikos_didaktika', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'lietuviu_filologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  [u'bendroji_muzikos_didaktika', u'naujuju_mediju_menas', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'biologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'socialine_politika', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'religijos_pedagogika', nan, 0.0],
#  [u'bendroji_muzikos_didaktika',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  [u'bendroji_muzikos_didaktika', u'etnologija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  [u'bendroji_muzikos_didaktika', u'baltijos_regiono_studijos', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'politikos_mokslai', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', 'viesoji_komunikacija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'vadyba', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'vokieciu_filologija', nan, nan],
#  [u'bendroji_muzikos_didaktika', 'energijos_technologijos', nan, nan],
#  [u'bendroji_muzikos_didaktika',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  [u'bendroji_muzikos_didaktika', u'verslo_administravimas', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'aplinkotyra', nan, nan],
#  [u'bendroji_muzikos_didaktika', u'psichologija', nan, 0.0],
#  [],
#  [u'bendroji_muzikos_didaktika', 'viesasis_administravimas', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'biochemija', nan, 0.0],
#  [u'bendroji_muzikos_didaktika', u'italistika_ir_romanu_kalbos', nan, nan],
#  [u'bendroji_muzikos_didaktika', 'teise', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'marketingo_vadyba', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'atlikimo_menas', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'istorija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', 'baltijos_regiono_kulturos', nan, nan],
#  [u'vokieciu_kalba_ir_kultura',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  [u'vokieciu_kalba_ir_kultura', u'kurybines_industrijos', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'prancuzu_filologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'lietuviu_kalba', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'kataliku_teologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'filosofija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'menotyra', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'energetikos_fizika', nan, nan],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'biotechnologija', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'muzikos_pedagogika', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'socialinis_darbas', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'anglu_filologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  [u'vokieciu_kalba_ir_kultura', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'ekonomika', nan, nan],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'lietuviu_filologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'naujuju_mediju_menas', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'biologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'socialine_politika', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'religijos_pedagogika', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  [u'vokieciu_kalba_ir_kultura', u'etnologija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  [u'vokieciu_kalba_ir_kultura', u'baltijos_regiono_studijos', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'politikos_mokslai', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', 'viesoji_komunikacija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'vadyba', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'vokieciu_filologija', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', 'energijos_technologijos', nan, nan],
#  [u'vokieciu_kalba_ir_kultura',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  [u'vokieciu_kalba_ir_kultura', u'verslo_administravimas', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'aplinkotyra', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', u'psichologija', nan, 0.0],
#  [],
#  [u'vokieciu_kalba_ir_kultura', 'viesasis_administravimas', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'biochemija', nan, 0.0],
#  [u'vokieciu_kalba_ir_kultura', u'italistika_ir_romanu_kalbos', nan, nan],
#  [u'vokieciu_kalba_ir_kultura', 'teise', nan, 0.0],
#  [u'prancuzu_filologija', u'marketingo_vadyba', 1.8181818181818183, 0.0],
#  [u'prancuzu_filologija', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'prancuzu_filologija', u'atlikimo_menas', 0.0, nan],
#  [u'prancuzu_filologija', u'istorija', 0.0, 0.0],
#  [u'prancuzu_filologija', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'prancuzu_filologija', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'prancuzu_filologija', u'kurybines_industrijos', 0.0, 0.0],
#  [u'prancuzu_filologija', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'prancuzu_filologija', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'prancuzu_filologija', u'prancuzu_filologija', 0.0, 0.0],
#  [u'prancuzu_filologija', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'prancuzu_filologija', u'lietuviu_kalba', 0.0, nan],
#  [u'prancuzu_filologija', u'kataliku_teologija', 0.0, 0.5],
#  [u'prancuzu_filologija', u'filosofija', 1.8181818181818183, 8.625],
#  [u'prancuzu_filologija', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'prancuzu_filologija', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'prancuzu_filologija', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'prancuzu_filologija', u'menotyra', 0.9090909090909092, 0.0],
#  [u'prancuzu_filologija', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'prancuzu_filologija', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'prancuzu_filologija', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'prancuzu_filologija', u'biotechnologija', 0.0, nan],
#  [u'prancuzu_filologija', u'muzikos_pedagogika', 0.0, nan],
#  [u'prancuzu_filologija', u'socialinis_darbas', 0.0, 0.0],
#  [u'prancuzu_filologija', u'anglu_filologija', 0.9090909090909092, 0.0],
#  [u'prancuzu_filologija', 'multimedija_ir_interneto_technologijos', 0.0, nan],
#  [u'prancuzu_filologija', u'matematika_ir_jos_taikymas', 0.0, 0.0],
#  [u'prancuzu_filologija', u'ekonomika', 0.0, nan],
#  [],
#  [u'prancuzu_filologija', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'prancuzu_filologija', u'lietuviu_filologija', 0.0, 0.9611650485436893],
#  [u'prancuzu_filologija',
#   u'multimedijos_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [],
#  [u'prancuzu_filologija', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'prancuzu_filologija', u'biologija', 0.0, 0.0],
#  [u'prancuzu_filologija', u'socialine_politika', 0.0, nan],
#  [u'prancuzu_filologija', u'religijos_pedagogika', 0.0, 0.358974358974359],
#  [u'prancuzu_filologija', u'rytu_azijos_saliu_kulturos_ir_kalbos', 0.0, 0.0],
#  [u'prancuzu_filologija', u'etnologija', 0.0, 0.0],
#  [u'prancuzu_filologija', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'prancuzu_filologija', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'prancuzu_filologija', u'politikos_mokslai', 0.0, 5.29082774049217],
#  [u'prancuzu_filologija', 'viesoji_komunikacija', 1.8181818181818183, 0.0],
#  [u'prancuzu_filologija', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'prancuzu_filologija', u'vadyba', 0.0, 0.0],
#  [u'prancuzu_filologija', u'vokieciu_filologija', 0.0, nan],
#  [u'prancuzu_filologija', 'energijos_technologijos', 0.0, nan],
#  [u'prancuzu_filologija',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.20454545454545453],
#  [u'prancuzu_filologija', u'verslo_administravimas', 0.0, 0.0],
#  [u'prancuzu_filologija', u'aplinkotyra', 0.0, nan],
#  [u'prancuzu_filologija', u'psichologija', 0.4545454545454546, 0.0],
#  [],
#  [u'prancuzu_filologija', 'viesasis_administravimas', 0.0, 0.0],
#  [u'prancuzu_filologija', u'biochemija', 0.0, 0.0],
#  [u'prancuzu_filologija',
#   u'italistika_ir_romanu_kalbos',
#   1.8181818181818183,
#   nan],
#  [u'prancuzu_filologija', 'teise', 0.0, 2.7129186602870816],
#  [u'anglu_ir_vokieciu_kalba', u'marketingo_vadyba', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'atlikimo_menas', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'istorija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', 'baltijos_regiono_kulturos', nan, nan],
#  [u'anglu_ir_vokieciu_kalba',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  [u'anglu_ir_vokieciu_kalba', u'kurybines_industrijos', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'prancuzu_filologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'lietuviu_kalba', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'kataliku_teologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'filosofija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'menotyra', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'energetikos_fizika', nan, nan],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'biotechnologija', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'muzikos_pedagogika', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'socialinis_darbas', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'anglu_filologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  [u'anglu_ir_vokieciu_kalba', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'ekonomika', nan, nan],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'lietuviu_filologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'naujuju_mediju_menas', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'biologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'socialine_politika', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'religijos_pedagogika', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  [u'anglu_ir_vokieciu_kalba', u'etnologija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  [u'anglu_ir_vokieciu_kalba', u'baltijos_regiono_studijos', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'politikos_mokslai', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', 'viesoji_komunikacija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'vadyba', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'vokieciu_filologija', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', 'energijos_technologijos', nan, nan],
#  [u'anglu_ir_vokieciu_kalba',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  [u'anglu_ir_vokieciu_kalba', u'verslo_administravimas', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'aplinkotyra', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', u'psichologija', nan, 0.0],
#  [],
#  [u'anglu_ir_vokieciu_kalba', 'viesasis_administravimas', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'biochemija', nan, 0.0],
#  [u'anglu_ir_vokieciu_kalba', u'italistika_ir_romanu_kalbos', nan, nan],
#  [u'anglu_ir_vokieciu_kalba', 'teise', nan, 0.0],
#  [u'lietuviu_kalba', u'marketingo_vadyba', nan, 0.0],
#  [u'lietuviu_kalba', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'lietuviu_kalba', u'atlikimo_menas', nan, nan],
#  [u'lietuviu_kalba', u'istorija', nan, 0.0],
#  [u'lietuviu_kalba', 'baltijos_regiono_kulturos', nan, nan],
#  [u'lietuviu_kalba', u'karjera_ir_profesinis_konsultavimas', nan, nan],
#  [u'lietuviu_kalba', u'kurybines_industrijos', nan, 0.0],
#  [u'lietuviu_kalba', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'lietuviu_kalba', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'lietuviu_kalba', u'prancuzu_filologija', nan, 0.0],
#  [u'lietuviu_kalba', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'lietuviu_kalba', u'lietuviu_kalba', nan, nan],
#  [u'lietuviu_kalba', u'kataliku_teologija', nan, 0.0],
#  [u'lietuviu_kalba', u'filosofija', nan, 0.0],
#  [u'lietuviu_kalba', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'lietuviu_kalba', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'lietuviu_kalba', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'lietuviu_kalba', u'menotyra', nan, 0.0],
#  [u'lietuviu_kalba', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'lietuviu_kalba', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'lietuviu_kalba', u'energetikos_fizika', nan, nan],
#  [],
#  [u'lietuviu_kalba', u'biotechnologija', nan, nan],
#  [u'lietuviu_kalba', u'muzikos_pedagogika', nan, nan],
#  [u'lietuviu_kalba', u'socialinis_darbas', nan, 0.0],
#  [u'lietuviu_kalba', u'anglu_filologija', nan, 0.0],
#  [u'lietuviu_kalba', 'multimedija_ir_interneto_technologijos', nan, nan],
#  [u'lietuviu_kalba', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'lietuviu_kalba', u'ekonomika', nan, nan],
#  [],
#  [u'lietuviu_kalba', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'lietuviu_kalba', u'lietuviu_filologija', nan, 0.0],
#  [u'lietuviu_kalba', u'multimedijos_ir_interneto_technologijos', nan, nan],
#  [],
#  [u'lietuviu_kalba', u'naujuju_mediju_menas', nan, 0.0],
#  [u'lietuviu_kalba', u'biologija', nan, 0.0],
#  [u'lietuviu_kalba', u'socialine_politika', nan, nan],
#  [u'lietuviu_kalba', u'religijos_pedagogika', nan, 0.0],
#  [u'lietuviu_kalba', u'rytu_azijos_saliu_kulturos_ir_kalbos', nan, 0.0],
#  [u'lietuviu_kalba', u'etnologija', nan, 0.0],
#  [u'lietuviu_kalba', 'sociologija_ir_antropologija', nan, 0.0],
#  [],
#  [u'lietuviu_kalba', u'baltijos_regiono_studijos', nan, nan],
#  [u'lietuviu_kalba', u'politikos_mokslai', nan, 0.0],
#  [u'lietuviu_kalba', 'viesoji_komunikacija', nan, 0.0],
#  [u'lietuviu_kalba', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'lietuviu_kalba', u'vadyba', nan, 0.0],
#  [u'lietuviu_kalba', u'vokieciu_filologija', nan, nan],
#  [u'lietuviu_kalba', 'energijos_technologijos', nan, nan],
#  [u'lietuviu_kalba', 'tarptautines_politikos_ir_vystymo_studijos', nan, 0.0],
#  [u'lietuviu_kalba', u'verslo_administravimas', nan, 0.0],
#  [u'lietuviu_kalba', u'aplinkotyra', nan, nan],
#  [u'lietuviu_kalba', u'psichologija', nan, 0.0],
#  [],
#  [u'lietuviu_kalba', 'viesasis_administravimas', nan, 0.0],
#  [u'lietuviu_kalba', u'biochemija', nan, 0.0],
#  [u'lietuviu_kalba', u'italistika_ir_romanu_kalbos', nan, nan],
#  [u'lietuviu_kalba', 'teise', nan, 0.0],
#  [u'kataliku_teologija', u'marketingo_vadyba', 0.0, 0.0],
#  [u'kataliku_teologija', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'kataliku_teologija', u'atlikimo_menas', 0.0, nan],
#  [u'kataliku_teologija', u'istorija', 0.0, 0.0],
#  [u'kataliku_teologija', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'kataliku_teologija', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'kataliku_teologija', u'kurybines_industrijos', 0.0, 0.3125],
#  [u'kataliku_teologija', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'kataliku_teologija', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'kataliku_teologija', u'prancuzu_filologija', 0.5, 0.0],
#  [u'kataliku_teologija', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'kataliku_teologija', u'lietuviu_kalba', 0.0, nan],
#  [u'kataliku_teologija', u'kataliku_teologija', 0.0, 0.0],
#  [u'kataliku_teologija', u'filosofija', 0.5, 0.0],
#  [u'kataliku_teologija', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'kataliku_teologija', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'kataliku_teologija', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'kataliku_teologija', u'menotyra', 0.0, 0.0],
#  [u'kataliku_teologija', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'kataliku_teologija', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'kataliku_teologija', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'kataliku_teologija', u'biotechnologija', 0.0, nan],
#  [u'kataliku_teologija', u'muzikos_pedagogika', 0.0, nan],
#  [u'kataliku_teologija', u'socialinis_darbas', 0.0, 0.0],
#  [u'kataliku_teologija', u'anglu_filologija', 0.5, 0.0],
#  [u'kataliku_teologija', 'multimedija_ir_interneto_technologijos', 0.0, nan],
#  [u'kataliku_teologija', u'matematika_ir_jos_taikymas', 0.0, 0.0],
#  [u'kataliku_teologija', u'ekonomika', 0.5, nan],
#  [],
#  [u'kataliku_teologija', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'kataliku_teologija', u'lietuviu_filologija', 0.0, 0.0],
#  [u'kataliku_teologija', u'multimedijos_ir_interneto_technologijos', 0.0, nan],
#  [],
#  [u'kataliku_teologija', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'kataliku_teologija', u'biologija', 0.0, 0.0],
#  [u'kataliku_teologija', u'socialine_politika', 0.0, nan],
#  [u'kataliku_teologija', u'religijos_pedagogika', 0.0, 0.358974358974359],
#  [u'kataliku_teologija', u'rytu_azijos_saliu_kulturos_ir_kalbos', 0.0, 0.0],
#  [u'kataliku_teologija', u'etnologija', 0.0, 0.0],
#  [u'kataliku_teologija', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'kataliku_teologija', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'kataliku_teologija', u'politikos_mokslai', 0.0, 0.0],
#  [u'kataliku_teologija', 'viesoji_komunikacija', 0.0, 0.0],
#  [u'kataliku_teologija', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'kataliku_teologija', u'vadyba', 0.0, 0.0],
#  [u'kataliku_teologija', u'vokieciu_filologija', 0.0, nan],
#  [u'kataliku_teologija', 'energijos_technologijos', 0.0, nan],
#  [u'kataliku_teologija',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.0],
#  [u'kataliku_teologija', u'verslo_administravimas', 0.0, 0.0],
#  [u'kataliku_teologija', u'aplinkotyra', 0.0, nan],
#  [u'kataliku_teologija',
#   u'psichologija',
#   0.16666666666666666,
#   14.813559322033898],
#  [],
#  [u'kataliku_teologija', 'viesasis_administravimas', 0.5, 0.0],
#  [u'kataliku_teologija', u'biochemija', 0.0, 0.0],
#  [u'kataliku_teologija', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'kataliku_teologija', 'teise', 0.0, 0.0],
#  [u'filosofija', u'marketingo_vadyba', 0.0, 0.0],
#  [u'filosofija', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'filosofija', u'atlikimo_menas', 0.0, nan],
#  [u'filosofija', u'istorija', 8.625, 1.5496598639455783],
#  [u'filosofija', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'filosofija', u'karjera_ir_profesinis_konsultavimas', 0.0, nan],
#  [u'filosofija', u'kurybines_industrijos', 0.0, 0.0],
#  [u'filosofija', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'filosofija', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'filosofija', u'prancuzu_filologija', 8.625, 1.8181818181818183],
#  [u'filosofija', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'filosofija', u'lietuviu_kalba', 0.0, nan],
#  [u'filosofija', u'kataliku_teologija', 0.0, 0.5],
#  [u'filosofija', u'filosofija', 0.0, 0.0],
#  [u'filosofija', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'filosofija', u'verslo_ir_taikomoji_informatika', 0.0, nan],
#  [u'filosofija', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'filosofija', u'menotyra', 8.625, 0.6616766467065869],
#  [u'filosofija', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'filosofija', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'filosofija', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'filosofija', u'biotechnologija', 0.0, nan],
#  [u'filosofija', u'muzikos_pedagogika', 0.0, nan],
#  [u'filosofija', u'socialinis_darbas', 0.0, 0.0],
#  [u'filosofija', u'anglu_filologija', 8.625, 2.8338192419825075],
#  [u'filosofija', 'multimedija_ir_interneto_technologijos', 0.0, nan],
#  [u'filosofija', u'matematika_ir_jos_taikymas', 2.875, 0.0],
#  [u'filosofija', u'ekonomika', 0.0, nan],
#  [],
#  [u'filosofija', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'filosofija', u'lietuviu_filologija', 0.0, 0.0],
#  [u'filosofija', u'multimedijos_ir_interneto_technologijos', 0.0, nan],
#  [],
#  [u'filosofija', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'filosofija', u'biologija', 0.0, 0.0],
#  [u'filosofija', u'socialine_politika', 0.0, nan],
#  [u'filosofija', u'religijos_pedagogika', 0.0, 0.0],
#  [u'filosofija', u'rytu_azijos_saliu_kulturos_ir_kalbos', 0.0, 0.0],
#  [u'filosofija', u'etnologija', 0.0, 0.6206896551724138],
#  [u'filosofija', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'filosofija', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'filosofija', u'politikos_mokslai', 1.078125, 2.645413870246085],
#  [u'filosofija', 'viesoji_komunikacija', 2.15625, 4.499290780141844],
#  [u'filosofija', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'filosofija', u'vadyba', 0.0, 0.0],
#  [u'filosofija', u'vokieciu_filologija', 0.0, nan],
#  [u'filosofija', 'energijos_technologijos', 0.0, nan],
#  [u'filosofija',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.20454545454545453],
#  [u'filosofija', u'verslo_administravimas', 8.625, 0.0],
#  [u'filosofija', u'aplinkotyra', 0.0, nan],
#  [u'filosofija', u'psichologija', 0.43125, 0.0],
#  [],
#  [u'filosofija', 'viesasis_administravimas', 0.0, 0.0],
#  [u'filosofija', u'biochemija', 0.0, 0.0],
#  [u'filosofija', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'filosofija', 'teise', 2.875, 0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   u'marketingo_vadyba',
#   0.17647058823529413,
#   0.0],
#  [u'anglu_ir_vokieciu_filologija', u'ekonomika_ir_finansai', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'atlikimo_menas', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'istorija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', 'baltijos_regiono_kulturos', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija',
#   u'karjera_ir_profesinis_konsultavimas',
#   0.0,
#   nan],
#  [u'anglu_ir_vokieciu_filologija', u'kurybines_industrijos', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'bendroji_muzikos_didaktika', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'vokieciu_kalba_ir_kultura', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'prancuzu_filologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'anglu_ir_vokieciu_kalba', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'lietuviu_kalba', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'kataliku_teologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'filosofija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'anglu_ir_vokieciu_filologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   u'verslo_ir_taikomoji_informatika',
#   0.0,
#   nan],
#  [u'anglu_ir_vokieciu_filologija', u'sociologija', 0.0, nan],
#  [],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'menotyra', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'aplinkotyra_ir_ekologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'aplinkosauga_ir_ekologija', 0.0, nan],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'energetikos_fizika', 0.0, nan],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'biotechnologija', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'muzikos_pedagogika', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'socialinis_darbas', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'anglu_filologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   'multimedija_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [u'anglu_ir_vokieciu_filologija', u'matematika_ir_jos_taikymas', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'ekonomika', 0.0, nan],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'mokymo_paslaugu_vadyba', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija',
#   u'lietuviu_filologija',
#   0.17647058823529413,
#   0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   u'multimedijos_ir_interneto_technologijos',
#   0.0,
#   nan],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'naujuju_mediju_menas', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'biologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   u'socialine_politika',
#   0.17647058823529413,
#   nan],
#  [u'anglu_ir_vokieciu_filologija', u'religijos_pedagogika', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   0.0,
#   0.0],
#  [u'anglu_ir_vokieciu_filologija', u'etnologija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', 'sociologija_ir_antropologija', 0.0, 0.0],
#  [],
#  [u'anglu_ir_vokieciu_filologija', u'baltijos_regiono_studijos', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija',
#   u'politikos_mokslai',
#   0.17647058823529413,
#   0.0],
#  [u'anglu_ir_vokieciu_filologija',
#   'viesoji_komunikacija',
#   0.0,
#   4.499290780141844],
#  [u'anglu_ir_vokieciu_filologija', u'mokymosi_paslaugu_vadyba', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', u'vadyba', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'vokieciu_filologija', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', 'energijos_technologijos', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   0.0,
#   0.0],
#  [u'anglu_ir_vokieciu_filologija', u'verslo_administravimas', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'aplinkotyra', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija',
#   u'psichologija',
#   0.17647058823529413,
#   14.813559322033898],
#  [],
#  [u'anglu_ir_vokieciu_filologija', 'viesasis_administravimas', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'biochemija', 0.0, 0.0],
#  [u'anglu_ir_vokieciu_filologija', u'italistika_ir_romanu_kalbos', 0.0, nan],
#  [u'anglu_ir_vokieciu_filologija', 'teise', 0.17647058823529413, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'marketingo_vadyba', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'atlikimo_menas', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'istorija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', 'baltijos_regiono_kulturos', nan, nan],
#  [u'verslo_ir_taikomoji_informatika',
#   u'karjera_ir_profesinis_konsultavimas',
#   nan,
#   nan],
#  [u'verslo_ir_taikomoji_informatika', u'kurybines_industrijos', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'prancuzu_filologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'lietuviu_kalba', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'kataliku_teologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'filosofija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   u'anglu_ir_vokieciu_filologija',
#   nan,
#   0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   u'verslo_ir_taikomoji_informatika',
#   nan,
#   nan],
#  [u'verslo_ir_taikomoji_informatika', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'menotyra', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'energetikos_fizika', nan, nan],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'biotechnologija', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'muzikos_pedagogika', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'socialinis_darbas', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'anglu_filologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   'multimedija_ir_interneto_technologijos',
#   nan,
#   nan],
#  [u'verslo_ir_taikomoji_informatika', u'matematika_ir_jos_taikymas', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'ekonomika', nan, nan],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'mokymo_paslaugu_vadyba', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'lietuviu_filologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   u'multimedijos_ir_interneto_technologijos',
#   nan,
#   nan],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'naujuju_mediju_menas', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'biologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'socialine_politika', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'religijos_pedagogika', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   nan,
#   0.0],
#  [u'verslo_ir_taikomoji_informatika', u'etnologija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   'sociologija_ir_antropologija',
#   nan,
#   0.0],
#  [],
#  [u'verslo_ir_taikomoji_informatika', u'baltijos_regiono_studijos', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'politikos_mokslai', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', 'viesoji_komunikacija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'mokymosi_paslaugu_vadyba', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'vadyba', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'vokieciu_filologija', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', 'energijos_technologijos', nan, nan],
#  [u'verslo_ir_taikomoji_informatika',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   nan,
#   0.0],
#  [u'verslo_ir_taikomoji_informatika', u'verslo_administravimas', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'aplinkotyra', nan, nan],
#  [u'verslo_ir_taikomoji_informatika', u'psichologija', nan, 0.0],
#  [],
#  [u'verslo_ir_taikomoji_informatika', 'viesasis_administravimas', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika', u'biochemija', nan, 0.0],
#  [u'verslo_ir_taikomoji_informatika',
#   u'italistika_ir_romanu_kalbos',
#   nan,
#   nan],
#  [u'verslo_ir_taikomoji_informatika', 'teise', nan, 0.0],
#  [u'sociologija', u'marketingo_vadyba', nan, 0.0],
#  [u'sociologija', u'ekonomika_ir_finansai', nan, 0.0],
#  [u'sociologija', u'atlikimo_menas', nan, nan],
#  [u'sociologija', u'istorija', nan, 4.648979591836735],
#  [u'sociologija', 'baltijos_regiono_kulturos', nan, nan],
#  [u'sociologija', u'karjera_ir_profesinis_konsultavimas', nan, nan],
#  [u'sociologija', u'kurybines_industrijos', nan, 0.0],
#  [u'sociologija', u'bendroji_muzikos_didaktika', nan, nan],
#  [u'sociologija', u'vokieciu_kalba_ir_kultura', nan, nan],
#  [u'sociologija', u'prancuzu_filologija', nan, 0.0],
#  [u'sociologija', u'anglu_ir_vokieciu_kalba', nan, nan],
#  [u'sociologija', u'lietuviu_kalba', nan, nan],
#  [u'sociologija', u'kataliku_teologija', nan, 0.0],
#  [u'sociologija', u'filosofija', nan, 0.0],
#  [u'sociologija', u'anglu_ir_vokieciu_filologija', nan, 0.0],
#  [u'sociologija', u'verslo_ir_taikomoji_informatika', nan, nan],
#  [u'sociologija', u'sociologija', nan, nan],
#  [],
#  [],
#  [u'sociologija', u'menotyra', nan, 0.0],
#  [u'sociologija', u'aplinkotyra_ir_ekologija', nan, 0.0],
#  [u'sociologija', u'aplinkosauga_ir_ekologija', nan, nan],
#  [],
#  [u'sociologija', u'energetikos_fizika', nan, nan],
#  ...]

# %%
gauk_tikruosius_svorius('filosofija','teise')
# Out:
# ['filosofija', 'teise', 2.875, 0.0]

# %%
DTTTTTT = pd.DataFrame(rex, columns=['pav1','pav2','wght1','wght2'])
DTTTTTT
# Out:
#                    pav1  \
# 0     marketingo_vadyba
# 1     marketingo_vadyba
# 2     marketingo_vadyba
# ...                 ...
# 3718              teise
# 3719              teise
# 3720              teise
#
#                              pav2  \
# 0               marketingo_vadyba
# 1           ekonomika_ir_finansai
# 2                  atlikimo_menas
# ...                           ...
# 3718                   biochemija
# 3719  italistika_ir_romanu_kalbos
# 3720                        teise
#
#          wght1  \
# 0     0.000000
# 1     0.688202
# 2     0.000000
# ...        ...
# 3718  0.000000
# 3719  5.425837
# 3720  0.000000
#
#          wght2
# 0     0.000000
# 1     0.329897
# 2          NaN
# ...        ...
# 3718  0.000000
# 3719       NaN
# 3720  0.000000
#
# [3721 rows x 4 columns]

# %%
import pandas as pd
rex = [x for x in rex if x]
#[len(x) for x in rex] #Check

names1 = [x[0] for x in rex] 
names2 = [x[1] for x in rex]
values = [x[2] for x in rex]

DATAFRAME = pd.DataFrame()
DATAFRAME = pd.DataFrame(rex,
                         columns=['pagr','gret','weight','weight2'])
DATAFRAME = DATAFRAME.dropna()
DATAFRAME = DATAFRAME[DATAFRAME.weight != 0].sort('weight')
DATAFRAME1 = DATAFRAME
DATAFRAME = DATAFRAME.drop('weight2', 1)

# %%
DATAFRAME1.weight
# Out:
# 2013    0.040541
# ...
# 2544    14.813559
# 2556    14.813559
# Name: weight, Length: 194, dtype: float64

# %%
fig = plt.figure(num=None,
                 figsize=(15, 15),
                 dpi=80,
                 facecolor='w',
                 edgecolor='k')

labels = zip(DATAFRAME1.pagr,DATAFRAME1.gret)
ax = fig.add_subplot(111)
ax.set_title(u'Neblogas grafas')
ax.set_xlabel(u'Kiek iseina')
ax.set_ylabel(u'Koks antros programos skaicius')
plt.scatter(DATAFRAME1.weight, 
            DATAFRAME1.weight2, 
            s=500, 
            c=[programos_fakulteto_spalva[x] for x in DATAFRAME1.pagr],
            alpha=0.7)

for label, x, y in zip(labels, DATAFRAME1.weight, DATAFRAME1.weight2):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (-10, 10),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.3', fc = 'grey', alpha = 0.1),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
pd2nx = DATAFRAME.T.to_dict()
pd2nx2 = [(pd2nx[x]['pagr'], pd2nx[x]['gret'], {'gretall': pd2nx[x]['weight']}) for x in DATAFRAME.index]

# %%
pd2nx2
# Out:
# [('sociologija_ir_antropologija', 'teise', {'gretall': 0.04054054054054054}),
#  (u'aplinkotyra_ir_ekologija',
#   u'biologija',
#   {'gretall': 0.045556805399325086}),
#  (u'aplinkotyra_ir_ekologija',
#   'viesoji_komunikacija',
#   {'gretall': 0.0531496062992126}),
#  ('viesasis_administravimas', 'teise', {'gretall': 0.06164789567279194}),
#  (u'socialinis_darbas', u'psichologija', {'gretall': 0.061930783242258654}),
#  (u'aplinkotyra_ir_ekologija',
#   u'biochemija',
#   {'gretall': 0.06377952755905512}),
#  (u'vadyba', u'ekonomika_ir_finansai', {'gretall': 0.07692307692307693}),
#  (u'kurybines_industrijos',
#   u'naujuju_mediju_menas',
#   {'gretall': 0.10416666666666666}),
#  (u'lietuviu_filologija',
#   'viesoji_komunikacija',
#   {'gretall': 0.11307824100513994}),
#  (u'matematika_ir_jos_taikymas',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.1458966565349544}),
#  (u'kurybines_industrijos', 'viesoji_komunikacija', {'gretall': 0.15625}),
#  (u'aplinkotyra_ir_ekologija',
#   u'psichologija',
#   {'gretall': 0.1594488188976378}),
#  (u'kataliku_teologija', u'psichologija', {'gretall': 0.16666666666666666}),
#  (u'anglu_ir_vokieciu_filologija',
#   u'psichologija',
#   {'gretall': 0.17647058823529413}),
#  (u'anglu_ir_vokieciu_filologija', 'teise', {'gretall': 0.17647058823529413}),
#  (u'anglu_ir_vokieciu_filologija',
#   u'politikos_mokslai',
#   {'gretall': 0.17647058823529413}),
#  (u'anglu_ir_vokieciu_filologija',
#   u'lietuviu_filologija',
#   {'gretall': 0.17647058823529413}),
#  (u'anglu_ir_vokieciu_filologija',
#   u'marketingo_vadyba',
#   {'gretall': 0.17647058823529413}),
#  (u'religijos_pedagogika', u'istorija', {'gretall': 0.1794871794871795}),
#  ('teise', u'psichologija', {'gretall': 0.18086124401913878}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   u'marketingo_vadyba',
#   {'gretall': 0.18421052631578946}),
#  (u'socialinis_darbas',
#   'viesasis_administravimas',
#   {'gretall': 0.18579234972677597}),
#  (u'naujuju_mediju_menas', u'psichologija', {'gretall': 0.19230769230769232}),
#  (u'biochemija', u'biologija', {'gretall': 0.196875}),
#  ('tarptautines_politikos_ir_vystymo_studijos',
#   u'prancuzu_filologija',
#   {'gretall': 0.20454545454545453}),
#  ('tarptautines_politikos_ir_vystymo_studijos',
#   u'filosofija',
#   {'gretall': 0.20454545454545453}),
#  ('tarptautines_politikos_ir_vystymo_studijos',
#   u'psichologija',
#   {'gretall': 0.20454545454545453}),
#  ('tarptautines_politikos_ir_vystymo_studijos',
#   'teise',
#   {'gretall': 0.20454545454545453}),
#  ('tarptautines_politikos_ir_vystymo_studijos',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.20454545454545453}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   'viesoji_komunikacija',
#   {'gretall': 0.2763157894736842}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   u'politikos_mokslai',
#   {'gretall': 0.2763157894736842}),
#  (u'socialinis_darbas', 'teise', {'gretall': 0.27868852459016397}),
#  ('viesoji_komunikacija',
#   u'marketingo_vadyba',
#   {'gretall': 0.28120567375886524}),
#  (u'verslo_administravimas', u'psichologija', {'gretall': 0.2942028985507246}),
#  (u'kurybines_industrijos', u'kataliku_teologija', {'gretall': 0.3125}),
#  (u'kurybines_industrijos', u'psichologija', {'gretall': 0.3125}),
#  (u'kurybines_industrijos', u'marketingo_vadyba', {'gretall': 0.3125}),
#  (u'kurybines_industrijos', u'menotyra', {'gretall': 0.3125}),
#  (u'anglu_filologija', u'psichologija', {'gretall': 0.31486880466472306}),
#  (u'aplinkotyra_ir_ekologija',
#   u'verslo_administravimas',
#   {'gretall': 0.3188976377952756}),
#  (u'aplinkotyra_ir_ekologija', u'menotyra', {'gretall': 0.3188976377952756}),
#  (u'aplinkotyra_ir_ekologija',
#   u'kurybines_industrijos',
#   {'gretall': 0.3188976377952756}),
#  (u'aplinkotyra_ir_ekologija',
#   u'marketingo_vadyba',
#   {'gretall': 0.3188976377952756}),
#  (u'ekonomika_ir_finansai', 'teise', {'gretall': 0.32989690721649484}),
#  (u'ekonomika_ir_finansai',
#   u'marketingo_vadyba',
#   {'gretall': 0.32989690721649484}),
#  (u'istorija', u'politikos_mokslai', {'gretall': 0.332069970845481}),
#  (u'politikos_mokslai', 'teise', {'gretall': 0.35272184936614465}),
#  (u'religijos_pedagogika',
#   u'prancuzu_filologija',
#   {'gretall': 0.358974358974359}),
#  (u'religijos_pedagogika',
#   u'kataliku_teologija',
#   {'gretall': 0.358974358974359}),
#  (u'religijos_pedagogika', u'psichologija', {'gretall': 0.358974358974359}),
#  (u'religijos_pedagogika',
#   u'lietuviu_filologija',
#   {'gretall': 0.358974358974359}),
#  (u'religijos_pedagogika', u'vadyba', {'gretall': 0.358974358974359}),
#  (u'naujuju_mediju_menas', u'menotyra', {'gretall': 0.38461538461538464}),
#  (u'naujuju_mediju_menas',
#   u'marketingo_vadyba',
#   {'gretall': 0.38461538461538464}),
#  (u'istorija', 'teise', {'gretall': 0.3874149659863946}),
#  (u'filosofija', u'psichologija', {'gretall': 0.43125}),
#  ('viesasis_administravimas',
#   u'aplinkotyra_ir_ekologija',
#   {'gretall': 0.4315352697095436}),
#  ('viesasis_administravimas',
#   u'verslo_administravimas',
#   {'gretall': 0.4315352697095436}),
#  ('viesasis_administravimas',
#   u'marketingo_vadyba',
#   {'gretall': 0.4315352697095436}),
#  ('viesasis_administravimas',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.4315352697095436}),
#  ('viesasis_administravimas',
#   u'psichologija',
#   {'gretall': 0.4315352697095436}),
#  (u'menotyra', 'viesoji_komunikacija', {'gretall': 0.44111776447105794}),
#  (u'verslo_administravimas',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.44130434782608696}),
#  (u'prancuzu_filologija', u'psichologija', {'gretall': 0.4545454545454546}),
#  (u'anglu_filologija',
#   'viesoji_komunikacija',
#   {'gretall': 0.4723032069970846}),
#  ('teise', u'politikos_mokslai', {'gretall': 0.4932579382340148}),
#  (u'kataliku_teologija', u'anglu_filologija', {'gretall': 0.5}),
#  (u'kataliku_teologija', u'filosofija', {'gretall': 0.5}),
#  (u'kataliku_teologija', 'viesasis_administravimas', {'gretall': 0.5}),
#  (u'kataliku_teologija', u'prancuzu_filologija', {'gretall': 0.5}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   u'istorija',
#   {'gretall': 0.5526315789473684}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   u'verslo_administravimas',
#   {'gretall': 0.5526315789473684}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   {'gretall': 0.5526315789473684}),
#  (u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.5526315789473684}),
#  (u'socialinis_darbas', u'politikos_mokslai', {'gretall': 0.5573770491803279}),
#  (u'socialinis_darbas',
#   'viesoji_komunikacija',
#   {'gretall': 0.5573770491803279}),
#  (u'anglu_filologija', 'teise', {'gretall': 0.5667638483965015}),
#  (u'etnologija', u'filosofija', {'gretall': 0.6206896551724138}),
#  (u'etnologija', u'politikos_mokslai', {'gretall': 0.6206896551724138}),
#  (u'etnologija', u'socialinis_darbas', {'gretall': 0.6206896551724138}),
#  (u'etnologija', 'viesoji_komunikacija', {'gretall': 0.6206896551724138}),
#  ('viesoji_komunikacija',
#   u'politikos_mokslai',
#   {'gretall': 0.642755825734549}),
#  (u'ekonomika_ir_finansai', u'psichologija', {'gretall': 0.6597938144329897}),
#  (u'ekonomika_ir_finansai',
#   u'verslo_administravimas',
#   {'gretall': 0.6597938144329897}),
#  (u'ekonomika_ir_finansai',
#   'viesoji_komunikacija',
#   {'gretall': 0.6597938144329897}),
#  (u'menotyra', u'filosofija', {'gretall': 0.6616766467065869}),
#  (u'menotyra', u'etnologija', {'gretall': 0.6616766467065869}),
#  (u'biologija', u'menotyra', {'gretall': 0.6763005780346821}),
#  (u'biologija', u'psichologija', {'gretall': 0.6763005780346821}),
#  (u'biologija', u'biochemija', {'gretall': 0.6763005780346821}),
#  (u'marketingo_vadyba',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.6882022471910112}),
#  (u'marketingo_vadyba', u'psichologija', {'gretall': 0.6882022471910112}),
#  (u'biochemija', u'matematika_ir_jos_taikymas', {'gretall': 0.7875}),
#  (u'biochemija', u'ekonomika_ir_finansai', {'gretall': 0.7875}),
#  (u'biochemija', u'anglu_filologija', {'gretall': 0.7875}),
#  (u'politikos_mokslai',
#   u'ekonomika_ir_finansai',
#   {'gretall': 0.8818046234153616}),
#  (u'verslo_administravimas',
#   u'politikos_mokslai',
#   {'gretall': 0.8826086956521739}),
#  ('teise', u'verslo_administravimas', {'gretall': 0.904306220095694}),
#  ('teise', u'ekonomika_ir_finansai', {'gretall': 0.904306220095694}),
#  (u'prancuzu_filologija',
#   u'anglu_filologija',
#   {'gretall': 0.9090909090909092}),
#  (u'prancuzu_filologija', u'menotyra', {'gretall': 0.9090909090909092}),
#  (u'anglu_filologija',
#   u'verslo_administravimas',
#   {'gretall': 0.9446064139941692}),
#  (u'lietuviu_filologija',
#   u'anglu_filologija',
#   {'gretall': 0.9611650485436893}),
#  (u'lietuviu_filologija', u'menotyra', {'gretall': 0.9611650485436893}),
#  (u'lietuviu_filologija',
#   u'prancuzu_filologija',
#   {'gretall': 0.9611650485436893}),
#  (u'matematika_ir_jos_taikymas',
#   u'psichologija',
#   {'gretall': 1.0212765957446808}),
#  (u'matematika_ir_jos_taikymas',
#   u'kurybines_industrijos',
#   {'gretall': 1.0212765957446808}),
#  (u'politikos_mokslai', u'istorija', {'gretall': 1.058165548098434}),
#  (u'filosofija', u'politikos_mokslai', {'gretall': 1.078125}),
#  (u'etnologija', u'menotyra', {'gretall': 1.2413793103448276}),
#  (u'politikos_mokslai', u'psichologija', {'gretall': 1.3227069351230425}),
#  (u'menotyra', u'psichologija', {'gretall': 1.3233532934131738}),
#  (u'menotyra', 'viesasis_administravimas', {'gretall': 1.3233532934131738}),
#  (u'menotyra', u'istorija', {'gretall': 1.3233532934131738}),
#  ('teise', u'marketingo_vadyba', {'gretall': 1.3564593301435408}),
#  ('teise', 'viesasis_administravimas', {'gretall': 1.3564593301435408}),
#  (u'marketingo_vadyba',
#   'viesoji_komunikacija',
#   {'gretall': 1.3764044943820224}),
#  (u'marketingo_vadyba',
#   u'verslo_administravimas',
#   {'gretall': 1.3764044943820224}),
#  (u'anglu_filologija', u'istorija', {'gretall': 1.4169096209912537}),
#  (u'anglu_filologija', u'politikos_mokslai', {'gretall': 1.4169096209912537}),
#  (u'anglu_filologija',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   {'gretall': 1.4169096209912537}),
#  ('viesoji_komunikacija', u'menotyra', {'gretall': 1.4997635933806144}),
#  ('viesoji_komunikacija',
#   'viesasis_administravimas',
#   {'gretall': 1.4997635933806144}),
#  ('viesoji_komunikacija',
#   u'verslo_administravimas',
#   {'gretall': 1.4997635933806144}),
#  ('viesoji_komunikacija', u'psichologija', {'gretall': 1.4997635933806144}),
#  (u'istorija', u'filosofija', {'gretall': 1.5496598639455783}),
#  (u'istorija', u'psichologija', {'gretall': 1.5496598639455783}),
#  ('teise', u'anglu_filologija', {'gretall': 1.808612440191388}),
#  ('teise', 'viesoji_komunikacija', {'gretall': 1.808612440191388}),
#  (u'prancuzu_filologija',
#   u'marketingo_vadyba',
#   {'gretall': 1.8181818181818183}),
#  (u'prancuzu_filologija',
#   'viesoji_komunikacija',
#   {'gretall': 1.8181818181818183}),
#  (u'prancuzu_filologija', u'filosofija', {'gretall': 1.8181818181818183}),
#  (u'lietuviu_filologija',
#   u'verslo_administravimas',
#   {'gretall': 1.9223300970873787}),
#  (u'lietuviu_filologija', u'psichologija', {'gretall': 1.9223300970873787}),
#  (u'filosofija', 'viesoji_komunikacija', {'gretall': 2.15625}),
#  ('viesoji_komunikacija',
#   'tarptautines_politikos_ir_vystymo_studijos',
#   {'gretall': 2.249645390070922}),
#  ('viesoji_komunikacija',
#   u'naujuju_mediju_menas',
#   {'gretall': 2.249645390070922}),
#  ('viesoji_komunikacija', 'teise', {'gretall': 2.249645390070922}),
#  ('viesoji_komunikacija',
#   'sociologija_ir_antropologija',
#   {'gretall': 2.249645390070922}),
#  (u'istorija',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   {'gretall': 2.3244897959183675}),
#  (u'istorija', u'anglu_filologija', {'gretall': 2.3244897959183675}),
#  (u'istorija', u'menotyra', {'gretall': 2.3244897959183675}),
#  (u'istorija', u'socialinis_darbas', {'gretall': 2.3244897959183675}),
#  (u'politikos_mokslai',
#   'viesoji_komunikacija',
#   {'gretall': 2.645413870246085}),
#  (u'politikos_mokslai',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   {'gretall': 2.645413870246085}),
#  (u'politikos_mokslai', u'filosofija', {'gretall': 2.645413870246085}),
#  ('teise', u'istorija', {'gretall': 2.7129186602870816}),
#  ('teise', u'prancuzu_filologija', {'gretall': 2.7129186602870816}),
#  (u'anglu_filologija',
#   'viesasis_administravimas',
#   {'gretall': 2.8338192419825075}),
#  (u'anglu_filologija', u'vadyba', {'gretall': 2.8338192419825075}),
#  (u'anglu_filologija',
#   u'lietuviu_filologija',
#   {'gretall': 2.8338192419825075}),
#  (u'anglu_filologija', u'filosofija', {'gretall': 2.8338192419825075}),
#  (u'anglu_filologija',
#   u'kurybines_industrijos',
#   {'gretall': 2.8338192419825075}),
#  (u'filosofija', u'matematika_ir_jos_taikymas', {'gretall': 2.875}),
#  (u'filosofija', 'teise', {'gretall': 2.875}),
#  (u'psichologija', u'verslo_administravimas', {'gretall': 3.7033898305084745}),
#  ('viesoji_komunikacija',
#   u'socialinis_darbas',
#   {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija',
#   u'anglu_ir_vokieciu_filologija',
#   {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija',
#   u'rytu_azijos_saliu_kulturos_ir_kalbos',
#   {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija', u'filosofija', {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija',
#   u'lietuviu_filologija',
#   {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija', u'istorija', {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija', u'anglu_filologija', {'gretall': 4.499290780141844}),
#  ('viesoji_komunikacija', u'vadyba', {'gretall': 4.499290780141844}),
#  (u'istorija', u'marketingo_vadyba', {'gretall': 4.648979591836735}),
#  (u'istorija', u'ekonomika_ir_finansai', {'gretall': 4.648979591836735}),
#  (u'istorija', u'kurybines_industrijos', {'gretall': 4.648979591836735}),
#  (u'istorija', u'religijos_pedagogika', {'gretall': 4.648979591836735}),
#  (u'istorija', u'etnologija', {'gretall': 4.648979591836735}),
#  (u'istorija', u'verslo_administravimas', {'gretall': 4.648979591836735}),
#  (u'istorija', 'viesoji_komunikacija', {'gretall': 4.648979591836735}),
#  (u'istorija', 'viesasis_administravimas', {'gretall': 4.648979591836735}),
#  (u'psichologija', 'teise', {'gretall': 4.937853107344633}),
#  (u'psichologija', 'viesoji_komunikacija', {'gretall': 4.937853107344633}),
#  (u'politikos_mokslai', u'marketingo_vadyba', {'gretall': 5.29082774049217}),
#  (u'politikos_mokslai',
#   u'verslo_administravimas',
#   {'gretall': 5.29082774049217}),
#  (u'politikos_mokslai', u'anglu_filologija', {'gretall': 5.29082774049217}),
#  (u'politikos_mokslai', u'prancuzu_filologija', {'gretall': 5.29082774049217}),
#  ('teise', u'menotyra', {'gretall': 5.425837320574163}),
#  (u'psichologija', u'anglu_filologija', {'gretall': 7.406779661016949}),
#  (u'psichologija', u'ekonomika_ir_finansai', {'gretall': 7.406779661016949}),
#  (u'filosofija', u'istorija', {'gretall': 8.625}),
#  (u'filosofija', u'anglu_filologija', {'gretall': 8.625}),
#  (u'filosofija', u'menotyra', {'gretall': 8.625}),
#  (u'filosofija', u'verslo_administravimas', {'gretall': 8.625}),
#  (u'filosofija', u'prancuzu_filologija', {'gretall': 8.625}),
#  (u'psichologija',
#   'sociologija_ir_antropologija',
#   {'gretall': 14.813559322033898}),
#  (u'psichologija',
#   u'anglu_ir_vokieciu_filologija',
#   {'gretall': 14.813559322033898}),
#  (u'psichologija',
#   u'aplinkotyra_ir_ekologija',
#   {'gretall': 14.813559322033898}),
#  (u'psichologija', u'socialinis_darbas', {'gretall': 14.813559322033898}),
#  (u'psichologija',
#   u'matematika_ir_jos_taikymas',
#   {'gretall': 14.813559322033898}),
#  (u'psichologija', u'religijos_pedagogika', {'gretall': 14.813559322033898}),
#  (u'psichologija', u'marketingo_vadyba', {'gretall': 14.813559322033898}),
#  (u'psichologija', u'kataliku_teologija', {'gretall': 14.813559322033898})]

# %%
from mpld3 import enable_notebook
enable_notebook()

G = nx.MultiDiGraph(pd2nx2)
#SG = G.subgraph([n for n, attrdict in G.node.items() 
#                 if (attrdict["fakultetas"] == "hmf"]) 
#                 or (attrdict["fakultetas"] == "smf"]) 
nx.draw(SG)

# %%
#x_pagrpop = dft[dft.pagr == x].drop_duplicates()['pagrpop'].values
#x_pagrall = dft[dft.pagr == x].drop_duplicates()['pagrall'].values

# %%
# Faculty pairs
# Better to do some of this with pandas.
# creates a list of dictionaries, where dictionaries represent relations between two. PAIR
mylist = []
for x in proglist:
    mydict = {}
    mydict['x'] = x
    
  #  lala = dfe.iloc['pagrpop','pagrviso']
    for y in proglist:
        mydict['y'] = y
        mydict['xy'] = [len(dfe[dfe['pagr'].isin([x]) & dfe['gret'].isin([y])])][0]
        mydict['yx'] = [len(dfe[dfe['pagr'].isin([y]) & dfe['pagr'].isin([x])])][0]
        mylist.append(mydict)
#some1 = [x['yx'] for x in mylist if x['xy'] > 1]
#some2 = [x['yx'] for x in mylist if x['yx'] > 1]

# %%
mylist[2]
# Out:
# {'x': u'marketingo_vadyba', 'xy': 0, 'y': 'teise', 'yx': 0}

# %% [markdown]
# ### 5.2.3 Faculty triplets

# %% [markdown]
# ## 5.3.1 Triplet(Clique) graphs

# %%
# Prie dfe prideti PASVERTA OUT

grpd = dfe[dfe.pagrpop > 0].sort('pagrpop', ascending=0)
drp = grpd.drop_duplicates(cols=['pagr', 'gret'])[['pagr', 'gret', 'pagrpop']]
THEGRAPH = nx.DiGraph()


dfl1 = drp['pagr'].tolist()
dfl2 = drp['gret'].tolist()
dfl3 = drp['pagrpop'].tolist()
dfl = zip(dfl1,
          dfl2,
          dfl3)

for x in range(len(dfl1)):
    THEGRAPH.add_edge(dfl1[x], dfl2[x])
    THEGRAPH[dfl1[x]][dfl2[x]]['weight'] = float(dfl3[x])
#PLOT THEGRAPH
# Out:
# C:\Users\Saonkfas\Anaconda\lib\site-packages\pandas\util\decorators.py:53: FutureWarning: cols is deprecated, use subset instead
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## STUDSEM

# %%
#rez = [dfe[dfe.pagr == x].groupby('studsem').size() for x in proglist] # get lots of dataframes
def get_all_studsems(x, pagr_or_gret): #By study program
    count = 0
    myarray = []
    mymainlist = []
    for z in range(8):
        count += 1
        if pagr_or_gret == 'pagr':
            rez = dfe[dfe.pagr == x]
        if pagr_or_gret == 'gret':
            rez = dfe[dfe.gret == x]
        rez = rez[rez.studsem == count]
        rez = len(rez)
    #    mydict[count] = np.array(rez)
        myarray.append(rez)
    mymainlist.append(np.array(myarray))
    return mymainlist

#get_all_studsems('filosofija') # TEST

# %%
import numpy as nphgf
rez_pagr = [get_all_studsems(x,'pagr') for x in proglist]
rez_gret = [get_all_studsems(x,'gret') for x in proglist]
DFT = pd.DataFrame(rez_pagr, proglist, ['studsem_cnts_pagr'])
DFT['studsem_cnts_gret'] = [x[0] for x in rez_gret]
#DFT.iloc[1,0]
#DFT.T.psichologija
DFT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-06dcf5f25c83> in <module>()
# ----> 1 rez_pagr = [get_all_studsems(x,'pagr') for x in proglist]
#       2 rez_gret = [get_all_studsems(x,'gret') for x in proglist]
#       3 DFT = pd.DataFrame(rez_pagr, proglist, ['studsem_cnts_pagr'])
#       4 DFT['studsem_cnts_gret'] = [x[0] for x in rez_gret]
#       5 #DFT.iloc[1,0]
#
# <ipython-input-64-099fa1c367f9> in get_all_studsems(x, pagr_or_gret)
#      14     #    mydict[count] = np.array(rez)
#      15         myarray.append(rez)
# ---> 16     mymainlist.append(np.array(myarray))
#      17     return mymainlist
#      18
#
# NameError: global name 'np' is not defined

# %%
def get_stats_of_array(arrayy):
    mylist = []       
    rez1 = [sum(arrayy[0:4]), sum(arrayy[4:8])] # Pirma metu puse, pries antra
    rez2 = [sum(arrayy[0::2]), sum(arrayy[1::2])] #Pavasaris pries rudeni.
    rez3 = [sum(arrayy[0:1]), sum(arrayy[2:3]), sum(arrayy[4:5]), sum(arrayy[6:7])]
    mylist.extend([rez1,rez2,rez3])
    return mylist

# Pagr
REX1 = [get_stats_of_array(DFT.iloc[x,0])[0] for x in range(len(DFT))]
REX2 = [get_stats_of_array(DFT.iloc[x,0])[1] for x in range(len(DFT))]
REX3 = [get_stats_of_array(DFT.iloc[x,0])[2] for x in range(len(DFT))]

DFT['prps_pagr'] = REX1
DFT['pvsrs_rd_pagr'] = REX2
DFT['ktr_mt_pagr'] = REX3

# Gret
REX4 = [get_stats_of_array(DFT.iloc[x,1])[0] for x in range(len(DFT))]
REX5 = [get_stats_of_array(DFT.iloc[x,1])[1] for x in range(len(DFT))]
REX6 = [get_stats_of_array(DFT.iloc[x,1])[2] for x in range(len(DFT))]

DFT['prps_gret'] = REX4
DFT['pvsrs_rd_gret'] = REX5
DFT['ktr_mt_gret'] = REX6
DFT

# %%
def PLOT_GRAPH(axis,threshold):
    for x in range(len(DFT)):
        if sum(DFT.iloc[x,axis]) > threshold:
            plt.plot(DFT.iloc[x,axis] / float(sum(DFT.iloc[x,axis])))
PLOT_GRAPH(0,20)

# %%
PLOT_GRAPH(1,20)

# %%
for x in range(len(DFT)):
    plt.plot(DFT.iloc[x,2])

# %%
for x in range(len(DFT)):
    plt.plot(DFT.iloc[x,3])

# %%
for x in range(len(DFT)):
    plt.plot(DFT.iloc[x,4])

# %%
import numpy as np
import pandas as pd
from pandas.tools.plotting import parallel_coordinates

a = dfn.loc[:,['m09','m10','m11','m12']].iloc[1]
b = dfn.loc[:,['m09','m10','m11','m12']].iloc[2]
c = dfn.loc[:,['m09','m10','m11','m12']].iloc[3]

#dfn
##[dfn.loc[:,['m09','m10','m11','m12']].iloc[1] for x in range(len(dfn))]
df = pd.DataFrame([dfn.loc[:,['m09','m10','m11','m12']].iloc[x] 
                   for x in range(len(dfn))], index=dfn.pavadinimas.values)

#from mpld3 import enable_notebook # Causes soooo much lag!
#enable_notebook() # Causes soooo much lag! Also too much of axis.
pd.scatter_matrix(df, 
                  diagonal='hist',
                  figsize=(7,7),
                  alpha=0.3,
                  marker='o',
                  c='k',
                  #c=[programos_fakulteto_spalva[x] for x in df.index],
                  s=100)

# %% [markdown]
# ## KITA

# %% [markdown]
# Turimea atsižvelgti, į tai, kiek studentų galėjo pasirinkti gretutines.

# %% [markdown]
# Now, lets create something that combines the two numbers.

# %% [markdown]
# ## Down to the individual level

# %%
# %qtconsole

# %% [markdown]
# The unique cases of choosing academic minor. The cases that oppose the dominant trends. Howe we can find them?

# %% [markdown]
# We did a lot already. But we did not assess any of the individual choices. It is very good, that we have made a throughout analysis of  the environment, but at the end, it is all about choices of individuals. So what are we interested in? We are interested in such things:
# o Can we find the motivation of the choice?
# o Can we assess the success of the choice?

# %%
prg1, prg2 = 'filosofija', 'psichologija'
[len(dfe[dfe['pagr'].isin([prg1]) & dfe['gret'].isin([prg2])])]

# %%
# Creating AFG(ALL FACULTY GRAPHS) this will make it easier to go through them. The graph is basically an EgoGraphf of Faculty
AFG = [nx.DiGraph for x in facultylist] # All Faculty Graphs
#add edges and nodes

# %%
G.edges(data=True)

# %%
# THIS PART IS GOOD!!!
# %matplotlib inline
import networkx as nx
pos = nx.fruchterman_reingold_layout(G)
plt.figure(figsize=(15, 15))
nx.draw_networkx(G, pos, with_labels=True) # unicod eproblems
plt.show()

# %%
# %matplotlib inline
pos = nx.fruchterman_reingold_layout(G)
plt.figure(figsize=(10, 10))
#nx.draw_networkx(SG, pos, with_labels=False)
nx.draw_networkx(G, pos, with_labels=True) # unicod eproblems
plt.show()
